# %%
# Import all the libraries
import pandas as pd
import glob
import os
import re
from pprint import pprint

# %%
#Get all CSV files in the folder of GA
all_files = glob.glob(r"C:\Huy Phan\College\VoterTurnout\data\GA\2016\*.csv")

# Files that contain both 'precinct' and 'general' in the filename
general_files = [
    f for f in all_files
    if all(word in f.lower() for word in ['precinct', 'general'])
]


# Files that contain both 'precinct' and 'primary' in the filename
primary_files = [
    f for f in all_files
    if all(word in f.lower() for word in ['precinct', 'primary', 'president'])
]

# %%
print("General files:")
for f in general_files:
    print(f)
# Out:
# General files:
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160119__ga__special__general__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160216__ga__special__general__runoff__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160329__ga__special__general__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160426__ga__special__general__runoff__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__appling__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__atkinson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__bacon__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__baker__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__baldwin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__banks__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__barrow__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__bartow__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__ben_hill__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__berrien__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__bibb__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__bleckley__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__brantley__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__brooks__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__bryan__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__bulloch__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__burke__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__butts__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__calhoun__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__camden__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__candler__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__carroll__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__catoosa__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__charlton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__chatham__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__chattahoochee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__chattooga__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__cherokee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__clarke__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__clayton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__clay__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__clinch__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__cobb__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__coffee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__colquitt__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__columbia__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__cook__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__coweta__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__crawford__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__crisp__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__dade__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__dawson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__decatur__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__dekalb__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__dodge__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__dooly__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__dougherty__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__douglas__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__early__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__echols__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__effingham__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__elbert__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__emanuel__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__evans__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__fannin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__fayette__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__floyd__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__forsyth__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__franklin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__fulton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__gilmer__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__glascock__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__glynn__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__gordon__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__grady__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__greene__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__gwinnett__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__habersham__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__hall__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__hancock__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__haralson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__harris__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__hart__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__heard__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__henry__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__houston__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__irwin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__jackson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__jasper__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__jefferson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__jeff_davis__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__jenkins__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__johnson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__jones__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__lamar__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__lanier__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__laurens__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__lee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__liberty__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__lincoln__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__long__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__lowndes__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__lumpkin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__macon__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__madison__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__marion__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__mcduffie__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__mcintosh__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__meriwether__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__miller__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__mitchell__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__monroe__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__montgomery__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__morgan__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__murray__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__muscogee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__newton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__oconee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__oglethorpe__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__paulding__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__peach__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__pickens__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__pierce__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__pike__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__polk__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__pulaski__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__putnam__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__quitman__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__rabun__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__randolph__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__richmond__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__rockdale__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__schley__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__screven__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__seminole__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__spalding__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__stephens__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__stewart__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__sumter__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__talbot__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__taliaferro__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__tattnall__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__taylor__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__telfair__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__terrell__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__thomas__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__tift__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__toombs__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__towns__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__treutlen__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__troup__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__turner__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__twiggs__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__union__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__upson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__walker__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__walton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__ware__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__warren__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__washington__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__wayne__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__webster__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__wheeler__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__white__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__whitfield__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__wilcox__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__wilkes__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__wilkinson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20161108__ga__general__worth__precinct.csv

# %%
print("\nPrimary files:")
for f in primary_files:
    print(f)
# Out:
# Primary files:
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__appling__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__atkinson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__bacon__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__baker__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__baldwin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__banks__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__barrow__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__bartow__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__ben_hill__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__berrien__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__bibb__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__bleckley__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__brantley__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__brooks__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__bryan__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__bulloch__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__burke__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__butts__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__calhoun__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__camden__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__candler__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__carroll__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__catoosa__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__charlton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__chatham__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__chattahoochee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__chattooga__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__cherokee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__clarke__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__clayton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__clay__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__clinch__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__cobb__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__coffee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__colquitt__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__columbia__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__cook__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__coweta__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__crawford__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__crisp__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__dade__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__dawson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__decatur__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__dekalb__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__dodge__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__dooly__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__dougherty__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__douglas__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__early__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__echols__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__effingham__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__elbert__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__emanuel__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__evans__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__fannin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__fayette__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__floyd__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__forsyth__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__franklin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__fulton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__gilmer__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__glascock__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__glynn__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__gordon__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__grady__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__greene__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__gwinnett__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__habersham__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__hall__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__hancock__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__haralson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__harris__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__hart__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__heard__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__henry__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__houston__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__irwin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__jackson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__jasper__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__jefferson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__jeff_davis__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__jenkins__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__johnson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__jones__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__lamar__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__lanier__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__laurens__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__lee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__liberty__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__lincoln__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__long__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__lowndes__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__lumpkin__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__macon__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__madison__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__marion__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__mcduffie__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__mcintosh__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__meriwether__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__miller__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__mitchell__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__monroe__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__montgomery__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__morgan__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__murray__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__muscogee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__newton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__oconee__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__oglethorpe__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__paulding__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__peach__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__pickens__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__pierce__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__pike__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__polk__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__pulaski__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__putnam__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__quitman__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__rabun__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__randolph__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__richmond__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__rockdale__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__schley__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__screven__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__seminole__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__spalding__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__stephens__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__stewart__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__sumter__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__talbot__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__taliaferro__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__tattnall__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__taylor__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__telfair__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__terrell__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__thomas__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__tift__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__toombs__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__towns__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__treutlen__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__troup__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__turner__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__twiggs__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__union__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__upson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__walker__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__walton__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__ware__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__warren__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__washington__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__wayne__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__webster__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__wheeler__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__white__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__whitfield__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__wilcox__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__wilkes__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__wilkinson__precinct.csv
# C:\Huy Phan\College\VoterTurnout\data\GA\2016\20160301__ga__primary__president__worth__precinct.csv

# %%
# Process primary files
primary_df_list = []

for file in primary_files:
    try:
        df = pd.read_csv(file)
        
        # Combine precinct as county + precinct
        df["precinct"] = df["county"].astype(str) + df["precinct"].astype(str)
        df["precinct"] = df["precinct"].str.upper()

        # Cleaning maybe total precinct
        if 'precinct' in df.columns:
            df['precinct'] = df['precinct'].astype(str)                  
            df = df[df['precinct'].str.upper() != "TOTAL"]               
            df = df[df['precinct'].str.strip().str.upper() != "TOTAL"]   
            df = df[df['precinct'].str.upper() != "NAN"]      
            df = df[~df['precinct'].str.upper().str.contains(r"\w*TOTAL\w*", na=False)]           
        
        if 'county' in df.columns:
            df['county'] = df['county'].astype(str)                  
            df = df[df['county'].str.upper() != "TOTAL"]               
            df = df[df['county'].str.strip().str.upper() != "TOTAL"]   
            df = df[df['county'].str.upper() != "NAN"]  
            df = df[~df['county'].str.upper().str.contains(r"\w*TOTAL\w*", na=False)]    

        # Filtering out only President 
        if 'office' in df.columns:
            df = df[df["office"] == "President"]
        
        # Dropping duplicates value
        df = df.drop_duplicates()
        
        primary_df_list.append(df)

    except Exception as e:
        print(f"Error in {file}: {e}")

# Combine all cleaned files
pri_combined_df = pd.concat(primary_df_list, ignore_index=True)

# Checking any suspicious precinct
suspicious_precincts = pri_combined_df[
    pri_combined_df["precinct"].str.strip().str.upper().isin(["TOTAL", "NAN"])
]
pri_combined_df
# Out:
#         county       precinct     office district party          candidate  \
# 0      Appling     APPLINGNAN  President      NaN   REP           JEB BUSH
# 1      Appling      APPLING1B  President      NaN   REP           JEB BUSH
# 2      Appling      APPLING1C  President      NaN   REP           JEB BUSH
# 3      Appling       APPLING2  President      NaN   REP           JEB BUSH
# 4      Appling      APPLING3A  President      NaN   REP           JEB BUSH
# ...        ...            ...        ...      ...   ...                ...
# 48581    Worth  WORTHSHINGLER  President      NaN   DEM  MICHAEL STEINBERG
# 48582    Worth  WORTHRED ROCK  President      NaN   DEM  MICHAEL STEINBERG
# 48583    Worth     WORTHDOLES  President      NaN   DEM  MICHAEL STEINBERG
# 48584    Worth  WORTHOAKFIELD  President      NaN   DEM  MICHAEL STEINBERG
# 48585    Worth   WORTHWARWICK  President      NaN   DEM  MICHAEL STEINBERG
#
#        votes  absentee_by_mail  election_day  advance_in_person  provisional  \
# 0         32                 5            20                7.0            0
# 1          5                 1             3                1.0            0
# 2          3                 1             2                0.0            0
# 3          3                 0             3                0.0            0
# 4          0                 0             0                0.0            0
# ...      ...               ...           ...                ...          ...
# 48581      1                 0             1                0.0            0
# 48582      0                 0             0                0.0            0
# 48583      0                 0             0                0.0            0
# 48584      0                 0             0                0.0            0
# 48585      0                 0             0                0.0            0
#
#        advance_in_person_1  advance_in_person_2  advance_in_person_3
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 48581                  NaN                  NaN                  NaN
# 48582                  NaN                  NaN                  NaN
# 48583                  NaN                  NaN                  NaN
# 48584                  NaN                  NaN                  NaN
# 48585                  NaN                  NaN                  NaN
#
# [48586 rows x 14 columns]

# %%
county_name_chatham = "CHATHAM"

pri_combined_df.loc[
    pri_combined_df["precinct"].str.contains(county_name_chatham, case=False, na=False),
    "precinct"
] = pri_combined_df["precinct"].str.extract(fr"^({county_name_chatham}[^\s]*)", flags=re.IGNORECASE)[0]

county_name2 = "GWINNETT"

# Extract parts only for rows that contain GWINNETT
mask = pri_combined_df["precinct"].str.contains(county_name2, case=False, na=False)
matches = pri_combined_df.loc[mask, "precinct"].str.extract(
    fr"^({county_name2})\d*\s+(.*)", flags=re.IGNORECASE
)

# Drop only unmatched GWINNETT rows
valid_mask = matches[0].notna()
pri_combined_df.loc[mask[mask].index[valid_mask], "precinct"] = (
    matches.loc[valid_mask, 0].str.upper() + matches.loc[valid_mask, 1]
)

county_name3 = "LOWNDES"

pri_combined_df.loc[
    pri_combined_df["precinct"].str.contains(county_name3, case=False, na=False),
    "precinct"
] = pri_combined_df["precinct"].str.extract(fr"^({county_name3}[^\s]*)", flags=re.IGNORECASE)[0]

# %%
# Select only the relevant columns
primary_data = pri_combined_df[["precinct", "party", "candidate", "votes"]]

primary_data
# Out:
#             precinct party          candidate  votes
# 0         APPLINGNAN   REP           JEB BUSH     32
# 1          APPLING1B   REP           JEB BUSH      5
# 2          APPLING1C   REP           JEB BUSH      3
# 3           APPLING2   REP           JEB BUSH      3
# 4          APPLING3A   REP           JEB BUSH      0
# ...              ...   ...                ...    ...
# 48581  WORTHSHINGLER   DEM  MICHAEL STEINBERG      1
# 48582  WORTHRED ROCK   DEM  MICHAEL STEINBERG      0
# 48583     WORTHDOLES   DEM  MICHAEL STEINBERG      0
# 48584  WORTHOAKFIELD   DEM  MICHAEL STEINBERG      0
# 48585   WORTHWARWICK   DEM  MICHAEL STEINBERG      0
#
# [48586 rows x 4 columns]

# %%
# Viewing candidate data
primary_data["candidate"].value_counts(dropna=False)
# Out:
# candidate
# JEB BUSH             2858
# BEN CARSON           2858
# MICHAEL STEINBERG    2858
# BERNIE SANDERS       2858
# MARTIN O'MALLEY      2858
# HILLARY CLINTON      2858
# DONALD J. TRUMP      2858
# RICK SANTORUM        2858
# MARCO RUBIO          2858
# RAND PAUL            2858
# GEORGE PATAKI        2858
# MIKE HUCKABEE        2858
# LINDSEY GRAHAM       2858
# CARLY FIORINA        2858
# TED CRUZ             2858
# CHRIS CHRISTIE       2858
# JOHN R. KASICH       2830
# JOHN R.KASICH          28
# Name: count, dtype: int64

# %%
# Cleaning Candidates

# Turning all primary data to uppercase
primary_data["candidate"] = primary_data["candidate"].astype(str).str.upper()

unwanted_keywords = [
    r"\w*VOTE\w*",
    r"\w*UNCOM\w*",
    r"\w*TOTAL\w*"
]

pattern = "|".join(unwanted_keywords)

# Assuming candidate column is already string and uppercase
primary_data = primary_data[~primary_data["candidate"].str.upper().str.contains(pattern, regex=True, na=False)]

# Fixing the , candidate
primary_data["candidate"] = (
    primary_data["candidate"].str.split(",")
    .str[0]
    .str.strip()
    )

# Fixing De la Fuente
primary_data.loc[
    primary_data["candidate"].str.contains("\w*Fuen\w*", case=False, na=False),
    "candidate"
] = "LA FUENTE"

#Selecting only last name
primary_data["candidate"] = primary_data["candidate"].str.split().str[-1]

# Fixing Huckabee
primary_data.loc[
    primary_data["candidate"].str.contains("\w*ABEE\w*", case=False, na=False),
    "candidate"
] = "HUCKABEE"

# Fixing Fiorina
primary_data.loc[
    primary_data["candidate"].str.contains("\w*ORINA\W*", case=False, na=False),
    "candidate"
] = "FIORINA"

# Fixing Gray
primary_data.loc[
    primary_data["candidate"].str.contains("GREY", case=False, na=False),
    "candidate"
] = "GRAY"

# Fixing Wilson
primary_data.loc[
    primary_data["candidate"].str.contains("WISON", case=False, na=False),
    "candidate"
] = "WILSON"

# Fixing Kasich
primary_data.loc[
    primary_data["candidate"].str.contains("\w*KASICH\W*", case=False, na=False),
    "candidate"
] = "KASICH"

# Fixing separator 
# primary_data["candidate"] = (
#     primary_data["candidate"]
#     .str.split(r"\s*(?:and|/|&|–|-|\+)\s*", n=1, expand=True)[0]
#     .str.strip()
#     .str.upper()
# )

# # Fixing McMullin

# primary_data.loc[
#     (
#         primary_data["candidate"].str.contains("MCMULLIN", case=False, na=False) |
#         primary_data["candidate"].str.contains("EVAN MCMULLEN", case=False, na=False)
#     ),
#     "candidate"
# ] = "MCMULLIN"

primary_data["candidate"].value_counts(dropna=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1436\3898376470.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primary_data["candidate"] = primary_data["candidate"].astype(str).str.upper()
# candidate
# BUSH         2858
# PAUL         2858
# SANDERS      2858
# O'MALLEY     2858
# CLINTON      2858
# TRUMP        2858
# SANTORUM     2858
# RUBIO        2858
# PATAKI       2858
# CARSON       2858
# KASICH       2858
# HUCKABEE     2858
# GRAHAM       2858
# FIORINA      2858
# CRUZ         2858
# CHRISTIE     2858
# STEINBERG    2858
# Name: count, dtype: int64

# %%
# Viewing Party
primary_data["party"].value_counts(dropna=False)
# Out:
# party
# REP    37154
# DEM    11432
# Name: count, dtype: int64

# %%
#=====================================
# This function is used to look up party
# for the candidate in the same df
#=====================================
def fill_party_from_data(row, df):
    if pd.notna(row["party"]):
        return row["party"]
    
    # Try to find other rows with the same candidate and known party
    matches = df[(df["candidate"] == row["candidate"]) & (df["party"].notna())]
    if not matches.empty:
        return matches["party"].iloc[0]  # Return the first match's party
    else:
        return None  # Still unknown
    

#=====================================
# Function to fill remaining missing party from master lookup
#=====================================
def fill_party_from_master(df, master_df):
    party_map = master_df.set_index("candidate")["party"].to_dict()
    df["party"] = df.apply(
        lambda row: party_map.get(row["candidate"], row["party"])
        if pd.isna(row["party"]) else row["party"],
        axis=1
    )
    return df


#=====================================
# Function to update the master candidate-party CSV
#=====================================
def update_master_candidate_party(df, master_path):
    # Read the existing master file
    master_df = pd.read_csv(master_path)
    
    # Combine unique pairs
    new_data = df[["candidate", "party"]].dropna().drop_duplicates()
    updated_master = pd.concat([master_df, new_data]).drop_duplicates(subset="candidate")

    # Save updated version
    updated_master.to_csv(master_path, index=False)


#=====================================
# Example usage (uncomment and modify for your workflow)
#=====================================
# Fill party using internal data
# primary_data["party"] = primary_data.apply(
#     lambda row: fill_party_from_data(row, primary_data),
#     axis=1
# )

# Fill remaining party using general master CSV
# master_party_df = pd.read_csv("data/master_primary_candidate_party.csv")
# general_data = fill_party_from_master(general_data, master_party_df)

# STEP 3: Update master file with new (candidate, party) pairs
# update_master_candidate_party(general_data, "data/master_candidate_party.csv")
primary_data["party"].value_counts(dropna=False)
# Out:
# party
# REP    37154
# DEM    11432
# Name: count, dtype: int64

# %%
# Cleaning Party
# primary_data["party"] = primary_data.apply(
#     lambda row: fill_party_from_data(row, primary_data),
#     axis=1
# )
# primary_data.loc[:,"party"] = (
#     primary_data["party"]
#     .replace({
#         "REPUBLICAN PARTY": "REP",
#         "R": "REP",
#         "Republican":"REP",
#         "DEMOCRATIC PARTY": "DEM",
#         "D": "DEM",
#         "Democratic": "DEM"
#     })
#     .fillna("IND")
# )
primary_data["party"].value_counts(dropna=False)
# Out:
# party
# REP    37154
# DEM    11432
# Name: count, dtype: int64

# %%
primary_data.loc[:,"candidate_column"] = (
    "pri_" +
    primary_data["party"].str.lower() + "_" +
    primary_data["candidate"]
)

# pivot the table
primary_result = primary_data.pivot_table(
    index="precinct",
    columns="candidate_column",
    values="votes",
    aggfunc="sum",  
    fill_value=0
).reset_index()

primary_result
# Out:
# candidate_column          precinct  pri_dem_CLINTON  pri_dem_O'MALLEY  \
# 0                        APPLING1B               23                 1
# 1                        APPLING1C               14                 1
# 2                         APPLING2              284                 3
# 3                        APPLING3A                1                 0
# 4                       APPLING3A1               11                 0
# ...                            ...              ...               ...
# 2852                 WORTHSHINGLER               19                 0
# 2853                   WORTHSUMNER               27                 0
# 2854              WORTHSYLVER EAST               46                 1
# 2855                WORTHSYLVESTER              314                 0
# 2856                  WORTHWARWICK               49                 0
#
# candidate_column  pri_dem_SANDERS  pri_dem_STEINBERG  pri_rep_BUSH  \
# 0                              12                  1             5
# 1                               5                  0             3
# 2                              41                  1             3
# 3                               3                  0             0
# 4                               6                  0             3
# ...                           ...                ...           ...
# 2852                            8                  1             3
# 2853                            6                  0             1
# 2854                           16                  1             7
# 2855                           38                  1             6
# 2856                           10                  0             2
#
# candidate_column  pri_rep_CARSON  pri_rep_CHRISTIE  pri_rep_CRUZ  \
# 0                             34                 0           108
# 1                             28                 0            88
# 2                             28                 0            45
# 3                             10                 0            41
# 4                             26                 0            68
# ...                          ...               ...           ...
# 2852                          12                 0            50
# 2853                          22                 0            56
# 2854                          36                 0            83
# 2855                          14                 1            82
# 2856                           8                 1            20
#
# candidate_column  pri_rep_FIORINA  pri_rep_GRAHAM  pri_rep_HUCKABEE  \
# 0                               1               0                 3
# 1                               0               1                 2
# 2                               0               0                 0
# 3                               0               0                 0
# 4                               0               0                 2
# ...                           ...             ...               ...
# 2852                            0               0                 0
# 2853                            0               0                 1
# 2854                            1               0                 2
# 2855                            1               0                 2
# 2856                            0               0                 0
#
# candidate_column  pri_rep_KASICH  pri_rep_PATAKI  pri_rep_PAUL  pri_rep_RUBIO  \
# 0                             12               0             0             54
# 1                              9               0             2             45
# 2                              7               0             0             27
# 3                              4               0             0             13
# 4                              4               0             0             18
# ...                          ...             ...           ...            ...
# 2852                           4               0             1             20
# 2853                           1               0             0             10
# 2854                          17               1             1             51
# 2855                          16               1             0             26
# 2856                           7               0             0             21
#
# candidate_column  pri_rep_SANTORUM  pri_rep_TRUMP
# 0                                0            165
# 1                                0            125
# 2                                0             96
# 3                                0             48
# 4                                0             59
# ...                            ...            ...
# 2852                             0            111
# 2853                             0            135
# 2854                             0            188
# 2855                             0            154
# 2856                             0            117
#
# [2857 rows x 18 columns]

# %%
# Process general files
general_df_list = []

for file in general_files:
    try:
        df = pd.read_csv(file)
        
        # Combine precinct as county + precinct
        df["precinct"] = df["county"].astype(str) + df["precinct"].astype(str)
        df["precinct"] = df["precinct"].str.upper()

        # Cleaning maybe total precinct
        if 'precinct' in df.columns:
            df['precinct'] = df['precinct'].astype(str)                  
            df = df[df['precinct'].str.upper() != "TOTAL"]               
            df = df[df['precinct'].str.strip().str.upper() != "TOTAL"]   
            df = df[df['precinct'].str.upper() != "NAN"]   
            df = df[~df['precinct'].str.upper().str.contains(r"\w*TOTAL\w*", na=False)]              
        
        if 'county' in df.columns:
            df['county'] = df['county'].astype(str)                  
            df = df[df['county'].str.upper() != "TOTAL"]               
            df = df[df['county'].str.strip().str.upper() != "TOTAL"]   
            df = df[df['county'].str.upper() != "NAN"]  
            df = df[~df['county'].str.upper().str.contains(r"\w*TOTAL\w*", na=False)]    
            
        # Filtering out only President 
        if 'office' in df.columns:
            df = df[df["office"] == "President of the United States"]
        
        # Dropping duplicates value
        df = df.drop_duplicates()
        
        general_df_list.append(df)

    except Exception as e:
        print(f"Error in {file}: {e}")

# Combine all cleaned files
gen_combined_df = pd.concat(general_df_list, ignore_index=True)

# Checking any suspicious precinct
suspicious_precincts = gen_combined_df[
    gen_combined_df["precinct"].str.strip().str.upper().isin(["TOTAL", "NAN"])
]

# %%
# cleaning 
# Fixing Canyon De Chelly
gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*BARROW08 FIRST BAPTIST CHURCH WINDER\w*", case=False, na=False),
    "precinct")
] = "BARROW08 HOLSENBECK ELEMENTARY SCHOOL"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*BROOKSBARWICK\w*", case=False, na=False),
    "precinct")
] = "BROOKSBARWICK/DRYLAKE"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*BROOKSBRIGGS\w*", case=False, na=False),
    "precinct")
] = "BROOKSE.BROOKS/BRIGGS"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*BROOKSNANKIN\w*", case=False, na=False),
    "precinct")
] = "BROOKSS.BROOKS/NANKIN"


gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*BRYANPUBLIC SAFETY\w*", case=False, na=False),
    "precinct")
] = "BRYANPUBLIC SAFETY COMPLEX"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*BRYANRH RECREATION\w*", case=False, na=False),
    "precinct")
] = "BRYANRH REC COMPLEX"


gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*CHARLTONFOLKSTON FIRE\w*", case=False, na=False),
    "precinct")
] = "CHARLTONFOLKSTON FIRE STATION"


county_name_chatham = "CHATHAM"

gen_combined_df.loc[
    gen_combined_df["precinct"].str.contains(county_name_chatham, case=False, na=False),
    "precinct"
] = gen_combined_df["precinct"].str.extract(fr"^({county_name_chatham}[^\s]*)", flags=re.IGNORECASE)[0]


gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*BROOKSPAVO\w*", case=False, na=False),
    "precinct")
] = "BROOKSPAVO/WILLIAMS"

county_name2 = "CRAWFORD"

gen_combined_df.loc[
    gen_combined_df["precinct"].str.contains(county_name2, case=False, na=False),
    "precinct"
] = gen_combined_df["precinct"].str.extract(fr"^({county_name2}[^\s]*)", flags=re.IGNORECASE)[0]



gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*FULTONJC18\w*", case=False, na=False),
    "precinct")
] = "FULTONJC18A"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*FULTONJC18\w*", case=False, na=False),
    "precinct")
] = "FULTONJC18A"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*FULTONJC13\w*", case=False, na=False),
    "precinct")
] = "FULTONJC13A"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*FULTONJC15\w*", case=False, na=False),
    "precinct")
] = "FULTONJC15A"


gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*GWINNETT035 CATES D - 04\w*", case=False, na=False),
    "precinct")
] = "GWINNETTCATES D - 04"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*SUMTERANDERSONV\w*", case=False, na=False),
    "precinct")
] = "SUMTERANDERSONVILLE"


gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*TELFAIRLUMBER-CITY\w*", case=False, na=False),
    "precinct")
] = "TELFAIRLUMBER CITY"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*APACHETEEC NOS POS\w*", case=False, na=False),
    "precinct")
] = "APACHETEEC"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*APACHEWIDE RUINS\w*", case=False, na=False),
    "precinct")
] = "APACHEWIDE"

# APACHEWINDOW ROCK
gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*APACHEWINDOW ROCK\w*", case=False, na=False),
    "precinct")
] = "APACHEWINDOW ROCK"
# LA PAZ058 QUARTZSITE TWO, THREE
gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*LA PAZ058 QUARTZSITE TWO\w*", case=False, na=False),
    "precinct")
] = "LA PAZ058 QUARTZSITE 2"
gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*LA PAZ058 QUARTZSITE THREE\w*", case=False, na=False),
    "precinct")
] = "LA PAZ058 QUARTZSITE 3"

# MOHAVE219-LAKE HAVASU NORTH N., S.
gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*MOHAVE219-LAKE HAVASU NORTH\w*", case=False, na=False),
    "precinct")
] = "MOHAVE219-LAKE HAVASU N."

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*MOHAVE219-LAKE HAVASU SOUTH\w*", case=False, na=False),
    "precinct")
] = "MOHAVE219-LAKE HAVASU S."

# PINALAPACHE JUNCTION E. CENTRAL,32,0,4,74
# PINALAPACHE JUNCTION N. CENTRAL,56,1,5,120
gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*PINALAPACHE JUNCTION E. CENTRAL\w*", case=False, na=False),
    "precinct")
] = "PINALAPACHE JUNCTION"

gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*PINALAPACHE JUNCTION N. CENTRAL\w*", case=False, na=False),
    "precinct")
] = "PINALAPACHE JUNCTION N. CENTRA"

# PINALCASA GRANDE S CENTRAL
gen_combined_df.loc[
    ( 
        gen_combined_df["precinct"].str.contains("\w*PINALCASA GRANDE S CENTRAL\w*", case=False, na=False),
    "precinct")
] = "PINALCASA GRANDE S CEN"

# %%
# Select only the relevant columns
general_data = gen_combined_df[["precinct", "party", "candidate", "votes"]]

general_data
# Out:
#            precinct party        candidate  votes
# 0        APPLINGNAN   REP  DONALD J. TRUMP   5494
# 1         APPLING1B   REP  DONALD J. TRUMP    685
# 2         APPLING1C   REP  DONALD J. TRUMP    496
# 3          APPLING2   REP  DONALD J. TRUMP    427
# 4         APPLING3A   REP  DONALD J. TRUMP    209
# ...             ...   ...              ...    ...
# 8551  WORTHSHINGLER   NaN     GARY JOHNSON      4
# 8552  WORTHRED ROCK   NaN     GARY JOHNSON      8
# 8553     WORTHDOLES   NaN     GARY JOHNSON      4
# 8554  WORTHOAKFIELD   NaN     GARY JOHNSON      1
# 8555   WORTHWARWICK   NaN     GARY JOHNSON      6
#
# [8556 rows x 4 columns]

# %%
# Viewing candidate data
general_data["candidate"].value_counts(dropna=False)
# Out:
# candidate
# DONALD J. TRUMP    2852
# HILLARY CLINTON    2852
# GARY JOHNSON       2852
# Name: count, dtype: int64

# %%
# Cleaning Candidates

# Turning all primary data to uppercase
# general_data["candidate"] = general_data["candidate"].astype(str).str.upper()


# unwanted_keywords = [
#     r"\w*VOTE\w*",
#     r"\w*UNCOM\w*",
#     r"\w*TOTAL\w*",
#     r"\w*WRITE[\s-]\w*",
#     r"NAN",
#     r"UNCERTIFIED",
#     r"UNVERIFIED",
#     r"NONE OF THE ABOVE",
#     r"LBT",
#     r"DEM",
#     r"REP",
#     r"GRN",
#     r"NAN"

# ]

# pattern = "|".join(unwanted_keywords)

# # FILTER OUT TRASH WORDS
# general_data = general_data[~general_data["candidate"].str.upper().str.contains(pattern, regex=True, na=False)]

# # Fixing Darrell Castle"
# general_data.loc[
#     general_data["candidate"].str.contains("\w*ASTLE\w*", case=False, na=False),
#     "candidate"
# ] = "CASTLE"

# general_data.loc[
#     general_data["candidate"].str.contains("\w*ATUREN\w*", case=False, na=False),
#     "candidate"
# ] = "MATUREN"

# # Fixing mixed president + vice_president by /
# general_data["candidate"] = (
#     general_data["candidate"].str.split("/")
#     .str[0]
#     .str.strip()
#     )

# #Selecting only last name
# general_data["candidate"] = general_data["candidate"].str.split().str[-1]

# # Fixing the , candidate
# # general_data["candidate"] = (
# #     general_data["candidate"].str.split(",")
# #     .str[0]
# #     .str.strip()
# #     )



# # Fixing Cubbler
# general_data.loc[
#     ( 
#         general_data["candidate"].str.contains("\w*UBBIER\w*", case=False, na=False)|
#         general_data["candidate"].str.contains("\w*UBLER\w*", case=False, na=False)|
#         general_data["candidate"].str.contains("\w*OBBLER\w*", case=False, na=False),
#     "candidate")
# ] = "CUBBLER"


# # Fixing Kotlikoff
# general_data.loc[
#     general_data["candidate"].str.contains("\w*TIKOFF\w*", case=False, na=False),
#     "candidate"
# ] = "KOTLIKOFF"

# # Fixing Valdivia
# general_data.loc[
#     general_data["candidate"].str.contains("\w*VALDIVA\W*", case=False, na=False),
#     "candidate"
# ] = "VALDIVIA"

# # Fixing HOEFLING
# general_data.loc[
#     general_data["candidate"].str.contains("\w*HOEFFLING", case=False, na=False),
#     "candidate"
# ] = "HOEFLING"


# # Fixing McMullin
# general_data.loc[
#     general_data["candidate"].str.contains("MCMULLEN", case=False, na=False) ,
#     "candidate"
# ] = "MCMULLIN"

general_data["candidate"].value_counts(dropna=False)
# Out:
# candidate
# DONALD J. TRUMP    2852
# HILLARY CLINTON    2852
# GARY JOHNSON       2852
# Name: count, dtype: int64

# %%
# Viewing Party
general_data["party"].value_counts(dropna=False)
# Out:
# party
# NaN    8511
# REP      15
# DEM      15
# LIB      15
# Name: count, dtype: int64

# %%
#=====================================
# This function is used to look up party
# for the candidate in the same df
#=====================================
def fill_party_from_data(row, df):
    if pd.notna(row["party"]):
        return row["party"]
    
    # Try to find other rows with the same candidate and known party
    matches = df[(df["candidate"] == row["candidate"]) & (df["party"].notna())]
    if not matches.empty:
        return matches["party"].iloc[0]  # Return the first match's party
    else:
        return None  # Still unknown
    

#=====================================
# Function to fill remaining missing party from master lookup
#=====================================
def fill_party_from_master(df, master_df):
    party_map = master_df.set_index("candidate")["party"].to_dict()
    df["party"] = df.apply(
        lambda row: party_map.get(row["candidate"], row["party"])
        if pd.isna(row["party"]) else row["party"],
        axis=1
    )
    return df


#=====================================
# Function to update the master candidate-party CSV
#=====================================
def update_master_candidate_party(df, master_path):
    # Read the existing master file
    master_df = pd.read_csv(master_path)

    # Filter and combine only known party entries (exclude 'UNK')
    new_data = (
        df[["candidate", "party"]]
        .dropna()
        .query('party != "UNK"')
        .drop_duplicates()
    )

    # Merge with master and remove duplicates by candidate
    updated_master = pd.concat([master_df, new_data]).drop_duplicates(subset="candidate")

    # Save updated version
    updated_master.to_csv(master_path, index=False)


#=====================================
# Example usage (uncomment and modify for your workflow)
#=====================================
# Fill party using internal data
general_data["party"] = general_data.apply(
    lambda row: fill_party_from_data(row, general_data),
    axis=1
)

# Fill remaining party using general master CSV
# master_party_df = pd.read_csv(r"C:\Huy Phan\College\VoterTurnout\data\cleaned_data\master_candidate_party.csv") # USE YOUR OWN ADDRESS
#  general_data = fill_party_from_master(general_data, master_party_df)
general_data["party"].value_counts(dropna=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1436\4206043947.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["party"] = general_data.apply(
# party
# REP    2852
# DEM    2852
# LIB    2852
# Name: count, dtype: int64

# %%
# Cleaning Party
# Turning all general data party to uppercase
general_data["party"] = general_data["party"].astype(str).str.upper()

general_data["party"] = (
    general_data["party"]
    .replace({
        "REPUBLICAN": "REP",
        "R": "REP",
        "DEMOCRATIC": "DEM",
        "DEM": "DEM",
        "D": "DEM",
        "GREEN": "GRN",
        "G": "GREEN",
        "LIBERTARIAN": "LIB",
        "LBT": "LIB",
        "L": "LIB",
        "CONSTITUTION": "CON",
        "NP": "IND",
        "NON": "IND",
        "WRI": "IND",
        "WRITE-IN": "IND",
        "ONA": "IND",
        "GEN": "IND",
        "NONE":"UNK"
    })
)

general_data["party"].value_counts(dropna=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1436\477868490.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["party"] = general_data["party"].astype(str).str.upper()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1436\477868490.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["party"] = (
# party
# REP    2852
# DEM    2852
# LIB    2852
# Name: count, dtype: int64

# %%
# UPDATE MASTER FILE, CAREFUL
update_master_candidate_party(general_data, r"C:\Huy Phan\College\VoterTurnout\data\cleaned_data\gen_can_party.csv")

# %%
general_data["candidate_column"] = (
    "gen_" +
    general_data["party"].str.lower() + "_" +
    general_data["candidate"].str.split().str[-1].str.upper()
)

# pivot the table
general_result = general_data.pivot_table(
    index="precinct",
    columns="candidate_column",
    values="votes",
    aggfunc="sum",  
    fill_value=0
).reset_index()

general_result
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1436\1829951435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["candidate_column"] = (
# candidate_column          precinct  gen_dem_CLINTON  gen_lib_JOHNSON  \
# 0                        APPLING1B               92                9
# 1                        APPLING1C               42                5
# 2                         APPLING2              742               10
# 3                        APPLING3A                4                4
# 4                       APPLING3A1               17                1
# ...                            ...              ...              ...
# 2841                 WORTHSHINGLER               47                4
# 2842                   WORTHSUMNER               91                3
# 2843              WORTHSYLVER EAST              162               25
# 2844                WORTHSYLVESTER              905               16
# 2845                  WORTHWARWICK              127                6
#
# candidate_column  gen_rep_TRUMP
# 0                           685
# 1                           496
# 2                           427
# 3                           209
# 4                           319
# ...                         ...
# 2841                        337
# 2842                        418
# 2843                        664
# 2844                        562
# 2845                        300
#
# [2846 rows x 4 columns]

# %%
# Merge
combined = pd.merge(primary_result, general_result, on="precinct", how="inner")

# Convert DEM primary columns to numeric and calculate total
dem_cols = combined.filter(like="pri_dem_").columns
combined[dem_cols] = combined[dem_cols].apply(pd.to_numeric, errors="coerce")
combined["dem_primary_total"] = combined[dem_cols].sum(axis=1)

# Convert general election columns to numeric and calculate total
gen_cols = combined.filter(like="gen_").columns
combined[gen_cols] = combined[gen_cols].apply(pd.to_numeric, errors="coerce")
combined["general_total"] = combined[gen_cols].sum(axis=1)

# Convert all numeric columns to int
for col in combined.columns[1:]:
    combined[col] = pd.to_numeric(combined[col], errors='coerce').fillna(0).astype(int)

# Save combined
combined.to_csv("TX.csv", index=False)

# Identify filtered-out precincts
primary_precincts = set(primary_result["precinct"])
general_precincts = set(general_result["precinct"])
combined_precincts = set(combined["precinct"])

primary_filtered_out = primary_precincts - combined_precincts
general_filtered_out = general_precincts - combined_precincts

# %%
combined.to_csv("GA.csv", index=False)
# Step 3: Identify unmatched precincts and retrieve full rows
combined_precincts = set(combined["precinct"])

# Rows in primary_result but not in combined
primary_filtered_out = primary_result[~primary_result["precinct"].isin(combined_precincts)]
primary_filtered_out.to_csv("GA_primary_filtered.csv", index=False)

# Rows in general_result but not in combined
general_filtered_out = general_result[~general_result["precinct"].isin(combined_precincts)]
general_filtered_out.to_csv("GA_general_filtered.csv", index=False)

# %%
print(f"primary: {len(primary_precincts)}, general: {len(general_precincts)}, combined: {len(combined)}")
# Out:
# primary: 2857, general: 2846, combined: 2821

# %%
print(f"primary: {len(pri_combined_df['county'].unique())}, general: {len(gen_combined_df['county'].unique())}")
# Out:
# primary: 159, general: 159
