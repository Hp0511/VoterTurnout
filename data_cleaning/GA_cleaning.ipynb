# %%
import pandas as pd
import glob
import os
from pprint import pprint

# %%
#Get all CSV files in the folder of GA
all_files = glob.glob(r"C:\Huy Phan\College\2025 summer scholar\data\GA\2016\*.csv")

# Files that contain both 'precinct' and 'general' in the filename
general_files = [f for f in all_files if 'precinct' in f.lower() and 'general' in f.lower()]

# Files that contain both 'precinct' and 'primary' in the filename

# %%
print("General files:")
for f in general_files:
    print(f)
# Out:
# General files:
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160119__ga__special__general__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160216__ga__special__general__runoff__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160329__ga__special__general__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160426__ga__special__general__runoff__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20161108__ga__general__appling__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20161108__ga__general__atkinson__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20161108__ga__general__bacon__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20161108__ga__general__baker__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20161108__ga__general__baldwin__precinct.csv
# ...

# %%
print("\nPrimary files:")
for f in primary_files:
    print(f)
# Out:
# Primary files:
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160301__ga__primary__president__appling__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160301__ga__primary__president__atkinson__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160301__ga__primary__president__bacon__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160301__ga__primary__president__baker__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160301__ga__primary__president__baldwin__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160301__ga__primary__president__banks__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160301__ga__primary__president__barrow__precinct.csv
# C:\Huy Phan\College\2025 summer scholar\data\GA\2016\20160301__ga__primary__president__bartow__precinct.csv
# ...

# %%
# Process general files

for file in primary_files:
    try:
        df = pd.read_csv(file)

        # Example cleaning: remove NAs
        df = df.drop_duplicates()
        df = df.dropna()

        df_list.append(df)
    except Exception as e:
        print(f"Error in {file}: {e}")

# Combine all cleaned files
combined_df = pd.concat(df_list, ignore_index=True)

# Example join with reference table
# reference_df = pd.read_csv("reference.csv")
# final_df = combined_df.merge(reference_df, on="id", how="left")

# Save result
combined_df.to_csv("combined_cleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 17
#      14         print(f"Error in {file}: {e}")
#      16 # Combine all cleaned files
# ---> 17 combined_df = pd.concat(df_list, ignore_index=True)
#      19 # Example join with reference table
#      20 # reference_df = pd.read_csv("reference.csv")
#      21 # final_df = combined_df.merge(reference_df, on="id", how="left")
#      22
#      23 # Save result
#      24 combined_df.to_csv("combined_cleaned.csv", index=False)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
# ...
