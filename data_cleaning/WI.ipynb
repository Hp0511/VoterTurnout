# %%
# Import all the libraries
import pandas as pd
import glob
import os
import re
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from pprint import pprint

# %%
#Get all CSV files in the folder of GA
all_files = glob.glob(r"C:\Huy Phan\College\VoterTurnout\data\WI\*.csv")

# Files that contain both 'precinct' and 'general' in the filename
general_files = [
    f for f in all_files
    if all(word in f.lower() for word in ['general'])
]

# Files that contain both 'precinct' and 'primary' in the filename
primary_files = [
    f for f in all_files
    if all(word in f.lower() for word in ['primary'])
]

# %%
print("General files:")
for f in general_files:
    print(f)
# Out:
# General files:
# C:\Huy Phan\College\VoterTurnout\data\WI\20160405__wi__general__ward.csv
# C:\Huy Phan\College\VoterTurnout\data\WI\20161108__wi__general__ward.csv

# %%
print("\nPrimary files:")
for f in primary_files:
    print(f)
# Out:
# Primary files:
# C:\Huy Phan\College\VoterTurnout\data\WI\20160216__wi__primary__ward.csv
# C:\Huy Phan\College\VoterTurnout\data\WI\20160405__wi__primary__ward.csv
# C:\Huy Phan\College\VoterTurnout\data\WI\20160809__wi__primary__ward.csv

# %%
# Process primary files
primary_df_list = []

for file in primary_files:
    try:
        df = pd.read_csv(file)
        # Filtering out only President 
        if 'office' in df.columns:
            df = df[df["office"] == "President"]
            
        # Combine precinct as county + precinct
        df["precinct"] = df["county"].astype(str) + df["ward"].astype(str)
        df["precinct"] = df["precinct"].str.upper()

        # Cleaning maybe total precinct
        if 'precinct' in df.columns:
            df['precinct'] = df['precinct'].astype(str)                  
            df = df[df['precinct'].str.upper() != "TOTAL"]               
            df = df[df['precinct'].str.strip().str.upper() != "TOTAL"]   
            df = df[df['precinct'].str.upper() != "NAN"]                
            df = df[~df['precinct'].str.upper().str.contains(r"\w*TOTAL\w*", na=False)]   

        if 'county' in df.columns:
            df['county'] = df['county'].astype(str)                  
            df = df[df['county'].str.upper() != "TOTAL"]               
            df = df[df['county'].str.strip().str.upper() != "TOTAL"]   
            df = df[df['county'].str.upper() != "NAN"]       
            df = df[~df['county'].str.upper().str.contains(r"\w*TOTAL\w*", na=False)]               
        
        # Dropping duplicates value
        df = df.drop_duplicates()
        primary_df_list.append(df)

    except Exception as e:
        print(f"Error in {file}: {e}")

# Combine all cleaned files
pri_combined_df = pd.concat(primary_df_list, ignore_index=True)
pri_combined_df
# Out:
#       county                                     ward     office  district  \
# 0      Adams                  Town Of Adams Wards 1-3  President       NaN
# 1      Adams                  Town Of Adams Wards 1-3  President       NaN
# 2      Adams                  Town Of Adams Wards 1-3  President       NaN
# 3      Adams                  Town Of Adams Wards 1-3  President       NaN
# 4      Adams                  Town Of Adams Wards 1-3  President       NaN
# ...      ...                                      ...        ...       ...
# 81475   Wood  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
# 81476   Wood  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
# 81477   Wood  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
# 81478   Wood  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
# 81479   Wood  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
#
#        total votes party                            candidate  votes  \
# 0              271   REP                          Marco Rubio      3
# 1              271   REP                           Ben Carson      0
# 2              271   REP                            Rand Paul      2
# 3              271   REP                        Mike Huckabee      1
# 4              271   REP                          Jim Gilmore      0
# ...            ...   ...                                  ...    ...
# 81475          775   DEM                      Martin O'Malley      3
# 81476          775   DEM                       Bernie Sanders    388
# 81477          775   DEM              Uninstructed Delegation      1
# 81478          775   DEM  Roque Rocky De La Fuente (Write-In)      0
# 81479          775   DEM                           Scattering      0
#
#                                           precinct
# 0                     ADAMSTOWN OF ADAMS WARDS 1-3
# 1                     ADAMSTOWN OF ADAMS WARDS 1-3
# 2                     ADAMSTOWN OF ADAMS WARDS 1-3
# 3                     ADAMSTOWN OF ADAMS WARDS 1-3
# 4                     ADAMSTOWN OF ADAMS WARDS 1-3
# ...                                            ...
# 81475  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
# 81476  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
# 81477  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
# 81478  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
# 81479  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
#
# [81480 rows x 9 columns]

# %%
#Load the filtered data
pri_filtered_out = pd.read_csv("WI_primary_filtered.csv")
gen_filtered_out = pd.read_csv("WI_general_filtered.csv")

# Get unique precinct names from primary_filtered_out and general_filtered_out
primary_precincts = pri_filtered_out["precinct"].dropna().unique()
general_precincts = gen_filtered_out["precinct"].dropna().unique()

# Create a mapping dictionary for precinct replacements
precinct_map = {}

# Loop through precincts in pri_filtered_out and find closest match in general_filtered_out
for p1 in primary_precincts:
    match, score = process.extractOne(p1, general_precincts, scorer=fuzz.token_sort_ratio)
    if score >= 90:  # Adjust threshold if needed
            precinct_map[p1] = match

# %%
# List of precincts to remove
# Fix for WAUPACACITY OF CLINTONVILLE WARD 2 to WARD 5
pri_combined_df.loc[
    (
        pri_combined_df["precinct"].str.contains("WAUPACACITY OF CLINTONVILLE WARD 2", case=False, na=False) |
        pri_combined_df["precinct"].str.contains("WAUPACACITY OF CLINTONVILLE WARD 3", case=False, na=False) |
        pri_combined_df["precinct"].str.contains("WAUPACACITY OF CLINTONVILLE WARD 4", case=False, na=False) |
        pri_combined_df["precinct"].str.contains("WAUPACACITY OF CLINTONVILLE WARD 5", case=False, na=False)
    ),
    "precinct"
] = "WAUPACACITY OF CLINTONVILLE WARD 1-7"

# Fix for BAYFIELDCITY OF WASHBURN WARD 1 to WARD 4
pri_combined_df.loc[
    (
        pri_combined_df["precinct"].str.contains("BAYFIELDCITY OF WASHBURN WARD 1", case=False, na=False) |
        pri_combined_df["precinct"].str.contains("BAYFIELDCITY OF WASHBURN WARD 2", case=False, na=False) |
        pri_combined_df["precinct"].str.contains("BAYFIELDCITY OF WASHBURN WARD 3", case=False, na=False) |
        pri_combined_df["precinct"].str.contains("BAYFIELDCITY OF WASHBURN WARD 4", case=False, na=False)
    ),
    "precinct"
] = "BAYFIELDCITY OF WASHBURN WARD 1-4"

# Fix for BAYFIELDTOWN OF EILEEN WARD 1 and 2
pri_combined_df.loc[
    (
        pri_combined_df["precinct"].str.contains("BAYFIELDTOWN OF EILEEN WARD 1", case=False, na=False) |
        pri_combined_df["precinct"].str.contains("BAYFIELDTOWN OF EILEEN WARD 2", case=False, na=False)
    ),
    "precinct"
] = "BAYFIELDTOWN OF EILEEN WARD 1-2"

precincts_to_remove = [
    "BARRONVILLAGE OF NEW AUBURN WARDS 2-3",
    "BROWNCITY OF DE PERE WARD 13",
    "BROWNCITY OF DE PERE WARDS 1-2,4",
    "BROWNCITY OF DE PERE WARDS 14-15",
    "BROWNCITY OF DE PERE WARDS 3-5",
    "BROWNTOWN OF NEW DENMARK WARD 3",
    "BROWNVILLAGE OF HOBART WARD 1-5",
    "BROWNVILLAGE OF HOBART WARD 6-9",
    "BROWNVILLAGE OF HOWARD WARD 13",
    "BROWNVILLAGE OF HOWARD WARD 14",
    "BROWNVILLAGE OF HOWARD WARD 15",
    "BROWNVILLAGE OF HOWARD WARD 16",   
    "BROWNVILLAGE OF HOWARD WARD 18",
    "BROWNVILLAGE OF HOWARD WARD 3-4",
    "BROWNVILLAGE OF HOWARD WARD 5-6",
    "BROWNVILLAGE OF HOWARD WARD 7-8",
    "DANECITY OF FITCHBURG WARD 1-4",
    "COLUMBIACITY OF WISCONSIN DELLS WARDS 1-3,6,11",
    "DANECITY OF STOUGHTON WARD 7-9",
    "DANETOWN OF CROSS PLAINS WARD 1-3",
    "DANETOWN OF VERONA WARD 1-4",
    "DANEVILLAGE OF BROOKLYN WARDS 1,3",
    "DANEVILLAGE OF DEFOREST WARD 7-13",
    "DANEVILLAGE OF WINDSOR WARDS 1-10",
    "WALWORTHCITY OF ELKHORN WARD 3",   
    "WALWORTHCITY OF ELKHORN WARD 4,8",
    "WALWORTHCITY OF ELKHORN WARD 6",
    "WALWORTHCITY OF WHITEWATER WARDS 7-9",
    "WALWORTHTOWN OF EAST TROY WARDS 1-6",
    "WASHINGTONCITY OF HARTFORD WARDS 1-5",
    "WASHINGTONCITY OF WEST BEND WARDS 11-14,28-29",
    "WASHINGTONCITY OF WEST BEND WARDS 9-10,30-32",
    "OUTAGAMIEVILLAGE OF COMBINED LOCKS WARDS 1-4",
    "WAUKESHATOWN OF BROOKFIELD WARD 1",
    "WAUKESHATOWN OF LISBON WARD 1",
    "WAUKESHATOWN OF LISBON WARD 6",    
    "WAUKESHATOWN OF LISBON WARD 2-3",
    "WAUKESHATOWN OF MUKWONAGO WARDS 1,4-8",
    "PORTAGECITY OF STEVENS POINT WARDS 14-15",
    "PORTAGECITY OF STEVENS POINT WARDS 25-26",
    "RACINEVILLAGE OF MOUNT PLEASANT WARDS 5-8",
    "WALWORTHCITY OF DELAVAN WARDS 11-14",
    "WALWORTHCITY OF LAKE GENEVA WARDS 5-6,10",

    
    ]

# Loop through the list and remove each key from precinct_map
for precinct in precincts_to_remove:
    if precinct in precinct_map:  # Check if the precinct exists in the map
        del precinct_map[precinct]  # Remove the key-value pair

pri_combined_df["precinct"] = pri_combined_df["precinct"].replace(precinct_map)

# %%
precinct_map
# Out:
# {'ADAMSCITY OF ADAMS WARD 1': 'ADAMSCITY OF ADAMS WARD 1-4',
#  'ADAMSCITY OF ADAMS WARD 2': 'ADAMSCITY OF ADAMS WARD 1-4',
#  'ADAMSCITY OF ADAMS WARD 3': 'ADAMSCITY OF ADAMS WARD 1-4',
#  'ADAMSCITY OF ADAMS WARD 4': 'ADAMSCITY OF ADAMS WARD 1-4',
#  'ADAMSTOWN OF EASTON WARD 1-2': 'ADAMSTOWN OF EASTON WARDS 1-2',
#  'ADAMSTOWN OF ROME WARDS 1-5': 'ADAMSTOWN OF ROME WARD 1-5',
#  'ASHLANDTOWN OF GORDON WARD 1': 'ASHLANDTOWN OF GORDON WARDS 1-2',
#  'ASHLANDTOWN OF GORDON WARD 2': 'ASHLANDTOWN OF GORDON WARDS 1-2',
#  'ASHLANDTOWN OF MARENGO WARD 1': 'ASHLANDTOWN OF MARENGO WARDS 1-2',
#  'ASHLANDTOWN OF MARENGO WARD 2': 'ASHLANDTOWN OF MARENGO WARDS 1-2',
#  'ASHLANDTOWN OF MORSE WARD 1': 'ASHLANDTOWN OF MORSE WARDS 1-3',
#  'ASHLANDTOWN OF MORSE WARD 2': 'ASHLANDTOWN OF MORSE WARDS 1-3',
#  'ASHLANDTOWN OF MORSE WARD 3': 'ASHLANDTOWN OF MORSE WARDS 1-3',
#  'ASHLANDTOWN OF PEEKSVILLE WARD 1': 'ASHLANDTOWN OF PEEKSVILLE WARDS 1-2',
#  'ASHLANDTOWN OF PEEKSVILLE WARD 2': 'ASHLANDTOWN OF PEEKSVILLE WARDS 1-2',
#  'CALUMETCITY OF CHILTON WARD 4': 'CALUMETCITY OF CHILTON WARD 1-5',
#  'CALUMETCITY OF CHILTON WARDS 2,5': 'CALUMETCITY OF CHILTON WARD 1-5',
#  'CALUMETCITY OF NEW HOLSTEIN WARD 3': 'CALUMETCITY OF NEW HOLSTEIN WARDS 1-5',
#  'CALUMETCITY OF NEW HOLSTEIN WARD 4': 'CALUMETCITY OF NEW HOLSTEIN WARDS 1-5',
#  'CALUMETCITY OF NEW HOLSTEIN WARD 5': 'CALUMETCITY OF NEW HOLSTEIN WARDS 1-5',
#  'CALUMETCITY OF NEW HOLSTEIN WARDS 1-2': 'CALUMETCITY OF NEW HOLSTEIN WARDS 1-5',
#  'CALUMETTOWN OF CHILTON WARD 1': 'CALUMETTOWN OF CHILTON WARDS 1-3',
#  'CALUMETTOWN OF CHILTON WARD 2': 'CALUMETTOWN OF CHILTON WARDS 1-3',
#  'CALUMETTOWN OF CHILTON WARD 3': 'CALUMETTOWN OF CHILTON WARDS 1-3',
#  'CALUMETTOWN OF HARRISON WARDS 7-8': 'CALUMETTOWN OF HARRISON WARDS 7-8,10-12',
#  'CALUMETTOWN OF NEW HOLSTEIN WARD 2': 'CALUMETTOWN OF NEW HOLSTEIN WARDS 1-3',
#  'CALUMETTOWN OF NEW HOLSTEIN WARDS 1,3': 'CALUMETTOWN OF NEW HOLSTEIN WARDS 1-3',
#  'CALUMETTOWN OF STOCKBRIDGE WARD 3': 'CALUMETTOWN OF STOCKBRIDGE WARDS 1-3',
#  'CALUMETTOWN OF STOCKBRIDGE WARDS 1-2': 'CALUMETTOWN OF STOCKBRIDGE WARDS 1-3',
#  'CALUMETVILLAGE OF SHERWOOD WARD 1': 'CALUMETVILLAGE OF SHERWOOD WARDS 1-5',
#  'CALUMETVILLAGE OF SHERWOOD WARD 5': 'CALUMETVILLAGE OF SHERWOOD WARDS 1-5',
#  'CALUMETVILLAGE OF SHERWOOD WARDS 2-4': 'CALUMETVILLAGE OF SHERWOOD WARDS 1-5',
#  'CHIPPEWATOWN OF BLOOMER WARD 1-2': 'CHIPPEWATOWN OF BLOOMER WARDS 1-2',
#  'CHIPPEWATOWN OF EAGLE POINT WARD 1-5': 'CHIPPEWATOWN OF EAGLE POINT WARDS 1-5',
#  'CHIPPEWATOWN OF EDSON WARD 1-2': 'CHIPPEWATOWN OF EDSON WARDS 1-2',
#  'CHIPPEWATOWN OF GOETZ WARD 1-2': 'CHIPPEWATOWN OF GOETZ WARDS 1-2',
#  'CHIPPEWATOWN OF LAKE HOLCOMBE WARD 1-2': 'CHIPPEWATOWN OF LAKE HOLCOMBE WARDS 1-2',
#  'CHIPPEWATOWN OF SIGEL WARD 1-2': 'CHIPPEWATOWN OF SIGEL WARDS 1-2',
#  'CHIPPEWATOWN OF TILDEN WARD 1-3': 'CHIPPEWATOWN OF TILDEN WARDS 1-3',
#  'CHIPPEWATOWN OF WHEATON WARD 1-3': 'CHIPPEWATOWN OF WHEATON WARDS 1-3',
#  'CHIPPEWAVILLAGE OF CADOTT WARD 1-3': 'CHIPPEWAVILLAGE OF CADOTT WARDS 1-3',
#  'CLARKCITY OF ABBOTSFORD WARD 2': 'CLARKCITY OF ABBOTSFORD WARDS 2-5',
#  'CLARKCITY OF ABBOTSFORD WARD 3': 'CLARKCITY OF ABBOTSFORD WARDS 2-5',
#  'CLARKCITY OF ABBOTSFORD WARD 4': 'CLARKCITY OF ABBOTSFORD WARDS 2-5',
#  'CLARKCITY OF ABBOTSFORD WARD 5': 'CLARKCITY OF ABBOTSFORD WARDS 2-5',
#  'CLARKCITY OF COLBY WARD 2': 'CLARKCITY OF COLBY WARDS 2-4',
#  'CLARKCITY OF COLBY WARD 3': 'CLARKCITY OF COLBY WARDS 2-4',
#  'CLARKCITY OF COLBY WARD 4': 'CLARKCITY OF COLBY WARDS 2-4',
#  'CLARKCITY OF GREENWOOD WARD 1': 'CLARKCITY OF GREENWOOD WARDS 1-2',
#  'CLARKCITY OF GREENWOOD WARD 2': 'CLARKCITY OF GREENWOOD WARDS 1-2',
#  'CLARKCITY OF LOYAL WARD 1': 'CLARKCITY OF LOYAL WARDS 1-2',
#  'CLARKCITY OF LOYAL WARD 2': 'CLARKCITY OF LOYAL WARDS 1-2',
#  'CLARKCITY OF OWEN WARD 1': 'CLARKCITY OF OWEN WARDS 1-3',
#  'CLARKCITY OF OWEN WARD 2': 'CLARKCITY OF OWEN WARDS 1-3',
#  'CLARKCITY OF OWEN WARD 3': 'CLARKCITY OF OWEN WARDS 1-3',
#  'CLARKCITY OF THORP WARD 1': 'CLARKCITY OF THORP WARDS 1-4',
#  'CLARKCITY OF THORP WARD 2': 'CLARKCITY OF THORP WARDS 1-4',
#  'CLARKCITY OF THORP WARD 3': 'CLARKCITY OF THORP WARDS 1-4',
#  'CLARKCITY OF THORP WARD 4': 'CLARKCITY OF THORP WARDS 1-4',
#  'CLARKTOWN OF COLBY WARD 1': 'CLARKTOWN OF COLBY WARDS 1-3',
#  'CLARKTOWN OF COLBY WARD 2': 'CLARKTOWN OF COLBY WARDS 1-3',
#  'CLARKTOWN OF COLBY WARD 3': 'CLARKTOWN OF COLBY WARDS 1-3',
#  'CLARKTOWN OF EATON WARD 1': 'CLARKTOWN OF EATON WARDS 1-2',
#  'CLARKTOWN OF EATON WARD 2': 'CLARKTOWN OF EATON WARDS 1-2',
#  'CLARKTOWN OF FREMONT WARD 1': 'CLARKTOWN OF FREMONT WARDS 1-2',
#  'CLARKTOWN OF FREMONT WARD 2': 'CLARKTOWN OF FREMONT WARDS 1-2',
#  'CLARKTOWN OF GRANT WARD 1': 'CLARKTOWN OF GRANT WARDS 1-2',
#  'CLARKTOWN OF GRANT WARD 2': 'CLARKTOWN OF GRANT WARDS 1-2',
#  'CLARKTOWN OF GREEN GROVE WARD 1': 'CLARKTOWN OF GREEN GROVE WARDS 1-2',
#  'CLARKTOWN OF GREEN GROVE WARD 2': 'CLARKTOWN OF GREEN GROVE WARDS 1-2',
#  'CLARKTOWN OF HEWETT WARD 1': 'CLARKTOWN OF HEWETT WARDS 1-2',
#  'CLARKTOWN OF HEWETT WARD 2': 'CLARKTOWN OF HEWETT WARDS 1-2',
#  'CLARKTOWN OF HIXON WARD 1': 'CLARKTOWN OF HIXON WARDS 1-2',
#  'CLARKTOWN OF HIXON WARD 2': 'CLARKTOWN OF HIXON WARDS 1-2',
#  'CLARKTOWN OF HOARD WARD 1': 'CLARKTOWN OF HOARD WARDS 1-2',
#  'CLARKTOWN OF HOARD WARD 2': 'CLARKTOWN OF HOARD WARDS 1-2',
#  'CLARKTOWN OF LEVIS WARD 1': 'CLARKTOWN OF LEVIS WARDS 1-2',
#  'CLARKTOWN OF LEVIS WARD 2': 'CLARKTOWN OF LEVIS WARDS 1-2',
#  'CLARKTOWN OF LONGWOOD WARD 1': 'CLARKTOWN OF LONGWOOD WARDS 1-2',
#  'CLARKTOWN OF LONGWOOD WARD 2': 'CLARKTOWN OF LONGWOOD WARDS 1-2',
#  'CLARKTOWN OF LOYAL WARD 1': 'CLARKTOWN OF LOYAL WARDS 1-2',
#  'CLARKTOWN OF LOYAL WARD 2': 'CLARKTOWN OF LOYAL WARDS 1-2',
#  'CLARKTOWN OF LYNN WARD 1': 'CLARKTOWN OF LYNN WARDS 1-2',
#  'CLARKTOWN OF LYNN WARD 2': 'CLARKTOWN OF LYNN WARDS 1-2',
#  'CLARKTOWN OF MAYVILLE WARD 1': 'CLARKTOWN OF MAYVILLE WARDS 1-2',
#  'CLARKTOWN OF MAYVILLE WARD 2': 'CLARKTOWN OF MAYVILLE WARDS 1-2',
#  'CLARKTOWN OF RESEBURG WARD 1': 'CLARKTOWN OF RESEBURG WARDS 1-2',
#  'CLARKTOWN OF RESEBURG WARD 2': 'CLARKTOWN OF RESEBURG WARDS 1-2',
#  'CLARKTOWN OF SHERMAN WARD 1': 'CLARKTOWN OF SHERMAN WARDS 1-2',
#  'CLARKTOWN OF SHERMAN WARD 2': 'CLARKTOWN OF SHERMAN WARDS 1-2',
#  'CLARKTOWN OF WARNER WARD 1': 'CLARKTOWN OF WARNER WARDS 1-2',
#  'CLARKTOWN OF WARNER WARD 2': 'CLARKTOWN OF WARNER WARDS 1-2',
#  'CLARKTOWN OF WESTON WARD 1': 'CLARKTOWN OF WESTON WARDS 1-2',
#  'CLARKTOWN OF WESTON WARD 2': 'CLARKTOWN OF WESTON WARDS 1-2',
#  'CLARKTOWN OF YORK WARD 1': 'CLARKTOWN OF YORK WARDS 1-2',
#  'CLARKTOWN OF YORK WARD 2': 'CLARKTOWN OF YORK WARDS 1-2',
#  'COLUMBIACITY OF COLUMBUS WARD 1-8,10': 'COLUMBIACITY OF COLUMBUS WARD 10',
#  'CRAWFORDTOWN OF CLAYTON WARD 1': 'CRAWFORDTOWN OF CLAYTON WARDS 1-3',
#  'CRAWFORDTOWN OF CLAYTON WARD 2': 'CRAWFORDTOWN OF CLAYTON WARDS 1-3',
#  'CRAWFORDTOWN OF CLAYTON WARD 3': 'CRAWFORDTOWN OF CLAYTON WARDS 1-3',
#  'CRAWFORDTOWN OF EASTMAN WARD 1': 'CRAWFORDTOWN OF EASTMAN WARDS 1-2',
#  'CRAWFORDTOWN OF EASTMAN WARD 2': 'CRAWFORDTOWN OF EASTMAN WARDS 1-2',
#  'CRAWFORDTOWN OF PRAIRIE DU CHIEN WARD 1': 'CRAWFORDTOWN OF PRAIRIE DU CHIEN WARDS 1-2',
#  'CRAWFORDTOWN OF PRAIRIE DU CHIEN WARD 2': 'CRAWFORDTOWN OF PRAIRIE DU CHIEN WARDS 1-2',
#  'CRAWFORDTOWN OF WAUZEKA WARD 1': 'CRAWFORDTOWN OF WAUZEKA WARDS 1-2',
#  'CRAWFORDTOWN OF WAUZEKA WARD 2': 'CRAWFORDTOWN OF WAUZEKA WARDS 1-2',
#  'DANECITY OF FITCHBURG WARD 10-14': 'DANECITY OF FITCHBURG WARD 14',
#  'DANECITY OF FITCHBURG WARD 5-9': 'DANECITY OF FITCHBURG WARDS 5-9',
#  'DANECITY OF FITCHBURG WARDS 15-20': 'DANECITY OF FITCHBURG WARD 20',
#  'DANECITY OF MIDDLETON WARDS 1-4,9,19-20': 'DANECITY OF MIDDLETON WARDS 1-4,9',
#  'DANECITY OF STOUGHTON WARD 1-2': 'DANECITY OF STOUGHTON WARDS 1-2',
#  'DANECITY OF STOUGHTON WARD 3-4,10-12': 'DANECITY OF STOUGHTON WARDS 3-4,12',
#  'DANECITY OF STOUGHTON WARD 5-6': 'DANECITY OF STOUGHTON WARDS 5-6',
#  'DANECITY OF SUN PRAIRIE WARD 1-5': 'DANECITY OF SUN PRAIRIE WARDS 1-5',
#  'DANECITY OF SUN PRAIRIE WARD 10-14,20': 'DANECITY OF SUN PRAIRIE WARDS 10-14',
#  'DANECITY OF SUN PRAIRIE WARD 15-19': 'DANECITY OF SUN PRAIRIE WARDS 15-19',
#  'DANECITY OF SUN PRAIRIE WARD 6-9': 'DANECITY OF SUN PRAIRIE WARDS 6-9',
#  'DANECITY OF VERONA WARD 1-5': 'DANECITY OF VERONA WARDS 1,5',
#  'DANECITY OF VERONA WARD 6-9': 'DANECITY OF VERONA WARDS 6-9',
#  'DANETOWN OF COTTAGE GROVE WARDS 1-7': 'DANETOWN OF COTTAGE GROVE WARDS 3,6',
#  'DANETOWN OF DUNKIRK WARD 1-6': 'DANETOWN OF DUNKIRK WARD 1,3,5',
#  'DANETOWN OF OREGON WARDS 1-4': 'DANETOWN OF OREGON WARD 1-4',
#  'DANETOWN OF SPRINGFIELD WARDS 1-3': 'DANETOWN OF SPRINGFIELD WARD 1-3',
#  'DANETOWN OF VIENNA WARD 1-2': 'DANETOWN OF VIENNA WARDS 1-2',
#  'DANEVILLAGE OF DEFOREST WARDS 1-6,14-17': 'DANEVILLAGE OF DEFOREST WARD 1,3-6,15',
#  'DODGECITY OF BEAVER DAM WARD 1,3,5': 'DODGECITY OF BEAVER DAM WARDS 1,3,5',
#  'DODGECITY OF BEAVER DAM WARD 2,6': 'DODGECITY OF BEAVER DAM WARDS 2,6',
#  'DODGECITY OF BEAVER DAM WARD 4,10': 'DODGECITY OF BEAVER DAM WARDS 4,10',
#  'DODGECITY OF BEAVER DAM WARD 7,12-13': 'DODGECITY OF BEAVER DAM WARDS 7,12-13',
#  'DODGECITY OF BEAVER DAM WARD 8,14': 'DODGECITY OF BEAVER DAM WARDS 8,14',
#  'DODGECITY OF BEAVER DAM WARD 9,11': 'DODGECITY OF BEAVER DAM WARDS 9,11',
#  'DODGECITY OF FOX LAKE WARD 1-3': 'DODGECITY OF FOX LAKE WARDS 1-3',
#  'DODGECITY OF WAUPUN WARD 1-8': 'DODGECITY OF WAUPUN WARDS 1-8',
#  'DODGETOWN OF ASHIPPUN WARD 1-4': 'DODGETOWN OF ASHIPPUN WARDS 1-4',
#  'DODGETOWN OF BEAVER DAM WARD 1-4,7-11': 'DODGETOWN OF BEAVER DAM WARDS 1-4,7-11',
#  'DODGETOWN OF BEAVER DAM WARD 5-6': 'DODGETOWN OF BEAVER DAM WARDS 5-6',
#  'DODGETOWN OF BURNETT WARD 1-2': 'DODGETOWN OF BURNETT WARDS 1-2',
#  'DODGETOWN OF CALAMUS WARD 1-2': 'DODGETOWN OF CALAMUS WARDS 1-2',
#  'DODGETOWN OF CHESTER WARD 1-2': 'DODGETOWN OF CHESTER WARDS 1-2',
#  'DODGETOWN OF EMMET WARD 1-2': 'DODGETOWN OF EMMET WARDS 1-2',
#  'DODGETOWN OF FOX LAKE WARD 1-4': 'DODGETOWN OF FOX LAKE WARDS 1-4',
#  'DODGETOWN OF HUBBARD WARD 1-4': 'DODGETOWN OF HUBBARD WARDS 1-4',
#  'DODGETOWN OF HUBBARD WARD 5-6': 'DODGETOWN OF HUBBARD WARDS 5-6',
#  'DODGETOWN OF HUSTISFORD WARD 1-2': 'DODGETOWN OF HUSTISFORD WARDS 1-2',
#  'DODGETOWN OF LEBANON WARD 1-2': 'DODGETOWN OF LEBANON WARDS 1-2',
#  'DODGETOWN OF LEROY WARD 1-2': 'DODGETOWN OF LEROY WARDS 1-2',
#  'DODGETOWN OF OAK GROVE WARD 1-2': 'DODGETOWN OF OAK GROVE WARDS 1-2',
#  'DODGETOWN OF OAK GROVE WARD 3-6': 'DODGETOWN OF OAK GROVE WARDS 3-6',
#  'DODGETOWN OF PORTLAND WARD 1-2': 'DODGETOWN OF PORTLAND WARDS 1-2',
#  'DODGETOWN OF RUBICON WARD 1-3': 'DODGETOWN OF RUBICON WARDS 1-3',
#  'DODGETOWN OF THERESA WARD 1,3-7': 'DODGETOWN OF THERESA WARDS 1,3-7',
#  'DODGETOWN OF TRENTON WARD 1-2': 'DODGETOWN OF TRENTON WARDS 1-2',
#  'DODGETOWN OF WILLIAMSTOWN WARD 1-3': 'DODGETOWN OF WILLIAMSTOWN WARDS 1-3',
#  'DODGEVILLAGE OF HUSTISFORD WARD 1-2': 'DODGEVILLAGE OF HUSTISFORD WARDS 1-2',
#  'DODGEVILLAGE OF RANDOLPH WARD 1-2': 'DODGEVILLAGE OF RANDOLPH WARDS 1-2',
#  'FORESTCITY OF CRANDON WARD 2': 'FORESTCITY OF CRANDON WARDS 1-4',
#  'FORESTCITY OF CRANDON WARD 3': 'FORESTCITY OF CRANDON WARDS 1-4',
#  'FORESTCITY OF CRANDON WARD 4': 'FORESTCITY OF CRANDON WARDS 1-4',
#  'FORESTTOWN OF ARGONNE WARD 1': 'FORESTTOWN OF ARGONNE WARDS 1-3',
#  'FORESTTOWN OF ARGONNE WARD 2': 'FORESTTOWN OF ARGONNE WARDS 1-3',
#  'FORESTTOWN OF ARGONNE WARD 3': 'FORESTTOWN OF ARGONNE WARDS 1-3',
#  'FORESTTOWN OF CRANDON WARD 1': 'FORESTTOWN OF CRANDON WARDS 1-3',
#  'FORESTTOWN OF CRANDON WARD 2': 'FORESTTOWN OF CRANDON WARDS 1-3',
#  'FORESTTOWN OF CRANDON WARD 3': 'FORESTTOWN OF CRANDON WARDS 1-3',
#  'FORESTTOWN OF LAONA WARD 1': 'FORESTTOWN OF LAONA WARDS 1-3',
#  'FORESTTOWN OF LAONA WARD 2': 'FORESTTOWN OF LAONA WARDS 1-3',
#  'FORESTTOWN OF LAONA WARD 3': 'FORESTTOWN OF LAONA WARDS 1-3',
#  'FORESTTOWN OF LINCOLN WARD 1': 'FORESTTOWN OF LINCOLN WARDS 1-3',
#  'FORESTTOWN OF LINCOLN WARD 2': 'FORESTTOWN OF LINCOLN WARDS 1-3',
#  'FORESTTOWN OF LINCOLN WARD 3': 'FORESTTOWN OF LINCOLN WARDS 1-3',
#  'FORESTTOWN OF WABENO WARD 1': 'FORESTTOWN OF WABENO WARDS 1-5',
#  'FORESTTOWN OF WABENO WARD 2': 'FORESTTOWN OF WABENO WARDS 1-5',
#  'FORESTTOWN OF WABENO WARD 3': 'FORESTTOWN OF WABENO WARDS 1-5',
#  'FORESTTOWN OF WABENO WARD 4': 'FORESTTOWN OF WABENO WARDS 1-5',
#  'FORESTTOWN OF WABENO WARD 5': 'FORESTTOWN OF WABENO WARDS 1-5',
#  'GRANTCITY OF FENNIMORE WARDS 1-4': 'GRANTCITY OF FENNIMORE WARD 1-4',
#  'GRANTTOWN OF HAZEL GREEN WARDS 1-2': 'GRANTTOWN OF HAZEL GREEN WARD 1-2',
#  'GRANTTOWN OF NORTH LANCASTER WARD 1-2': 'GRANTTOWN OF NORTH LANCASTER WARDS 1-2',
#  'GREEN LAKECITY OF BERLIN WARDS 1-6': 'GREEN LAKECITY OF BERLIN WARD 1-6',
#  'GREEN LAKETOWN OF BERLIN WARDS 1-3': 'GREEN LAKETOWN OF BERLIN WARD 1-3',
#  'GREENCITY OF BRODHEAD WARD 1': 'GREENCITY OF BRODHEAD WARDS 1-6',
#  'GREENCITY OF BRODHEAD WARD 2': 'GREENCITY OF BRODHEAD WARDS 1-6',
#  'GREENCITY OF BRODHEAD WARD 3': 'GREENCITY OF BRODHEAD WARDS 1-6',
#  'GREENCITY OF BRODHEAD WARD 4': 'GREENCITY OF BRODHEAD WARDS 1-6',
#  'GREENCITY OF BRODHEAD WARD 5': 'GREENCITY OF BRODHEAD WARDS 1-6',
#  'GREENCITY OF BRODHEAD WARD 6': 'GREENCITY OF BRODHEAD WARDS 1-6',
#  'GREENCITY OF MONROE WARD 1': 'GREENCITY OF MONROE WARDS 1-9',
#  'GREENCITY OF MONROE WARD
#  'MILWAUKEEVILLAGE OF HALES CORNERS WARD 1-3': 'MILWAUKEEVILLAGE OF HALES CORNERS WARDS 1-3',
#  'MILWAUKEEVILLAGE OF HALES CORNERS WARD 4-6': 'MILWAUKEEVILLAGE OF HALES CORNERS WARDS 4-6',
#  'MILWAUKEEVILLAGE OF HALES CORNERS WARD 7-9': 'MILWAUKEEVILLAGE OF HALES CORNERS WARDS 7-9',
#  'MILWAUKEEVILLAGE OF RIVER HILLS WARD 1': 'MILWAUKEEVILLAGE OF RIVER HILLS WARDS 1-3',
#  'MILWAUKEEVILLAGE OF RIVER HILLS WARD 2': 'MILWAUKEEVILLAGE OF RIVER HILLS WARDS 1-3',
#  'MILWAUKEEVILLAGE OF RIVER HILLS WARD 3': 'MILWAUKEEVILLAGE OF RIVER HILLS WARDS 1-3',
#  'MONROECITY OF SPARTA WARDS 13-16,20': 'MONROECITY OF SPARTA WARDS 13-18,20',
#  'MONROECITY OF SPARTA WARDS 7-12,17-19': 'MONROECITY OF SPARTA WARDS 7-12',
#  'MONROECITY OF TOMAH WARDS 9-13,18': 'MONROECITY OF TOMAH WARDS 12-16,18',
#  'MONROETOWN OF LA GRANGE WARD 1A': 'MONROETOWN OF LA GRANGE WARDS 1A-3A',
#  'MONROETOWN OF LA GRANGE WARD 1B': 'MONROETOWN OF LA GRANGE WARDS 1B-3B',
#  'OCONTOCITY OF GILLETT WARD 1-3': 'OCONTOCITY OF GILLETT WARDS 1-3',
#  'ONEIDACITY OF RHINELANDER WARD 11': 'ONEIDACITY OF RHINELANDER WARDS 11-12',
#  'ONEIDACITY OF RHINELANDER WARD 12': 'ONEIDACITY OF RHINELANDER WARDS 11-12',
#  'ONEIDACITY OF RHINELANDER WARD 13': 'ONEIDACITY OF RHINELANDER WARDS 13-14',
#  'ONEIDACITY OF RHINELANDER WARD 14': 'ONEIDACITY OF RHINELANDER WARDS 13-14',
#  'ONEIDACITY OF RHINELANDER WARD 2': 'ONEIDACITY OF RHINELANDER WARDS 2-3',
#  'ONEIDACITY OF RHINELANDER WARD 3': 'ONEIDACITY OF RHINELANDER WARDS 2-3',
#  'ONEIDACITY OF RHINELANDER WARD 4': 'ONEIDACITY OF RHINELANDER WARDS 4-5',
#  'ONEIDACITY OF RHINELANDER WARD 5': 'ONEIDACITY OF RHINELANDER WARDS 4-5',
#  'ONEIDACITY OF RHINELANDER WARD 6': 'ONEIDACITY OF RHINELANDER WARDS 6-7',
#  'ONEIDACITY OF RHINELANDER WARD 7': 'ONEIDACITY OF RHINELANDER WARDS 6-7',
#  'ONEIDACITY OF RHINELANDER WARD 8': 'ONEIDACITY OF RHINELANDER WARDS 8-9',
#  'ONEIDACITY OF RHINELANDER WARD 9': 'ONEIDACITY OF RHINELANDER WARDS 8-9',
#  'ONEIDATOWN OF CASSIAN WARD 1': 'ONEIDATOWN OF CASSIAN WARDS 1-2',
#  'ONEIDATOWN OF CASSIAN WARD 2': 'ONEIDATOWN OF CASSIAN WARDS 1-2',
#  'OUTAGAMIECITY OF SEYMOUR WARDS 5-6': 'OUTAGAMIECITY OF SEYMOUR WARDS 1-6',
#  'OUTAGAMIETOWN OF BOVINA WARD 1': 'OUTAGAMIETOWN OF BOVINA WARDS 1-2',
#  'OUTAGAMIETOWN OF BOVINA WARD 2': 'OUTAGAMIETOWN OF BOVINA WARDS 1-2',
#  'OUTAGAMIETOWN OF BUCHANAN WARD 10': 'OUTAGAMIETOWN OF BUCHANAN WARDS 1-10',
#  'OUTAGAMIETOWN OF BUCHANAN WARD 5': 'OUTAGAMIETOWN OF BUCHANAN WARDS 1-10',
#  'OUTAGAMIETOWN OF BUCHANAN WARDS 1,4,6-9': 'OUTAGAMIETOWN OF BUCHANAN WARDS 1-10',
#  'OUTAGAMIETOWN OF BUCHANAN WARDS 2-3': 'OUTAGAMIETOWN OF BUCHANAN WARDS 1-10',
#  'OUTAGAMIETOWN OF DALE WARD 3': 'OUTAGAMIETOWN OF DALE WARDS 1-3',
#  'OUTAGAMIETOWN OF DALE WARDS 1-2': 'OUTAGAMIETOWN OF DALE WARDS 1-3',
#  'OUTAGAMIETOWN OF ELLINGTON WARD 3': 'OUTAGAMIETOWN OF ELLINGTON WARDS 1-5',
#  'OUTAGAMIETOWN OF ELLINGTON WARD 5': 'OUTAGAMIETOWN OF ELLINGTON WARDS 1-5',
#  'OUTAGAMIETOWN OF ELLINGTON WARDS 1-2,4': 'OUTAGAMIETOWN OF ELLINGTON WARDS 1-5',
#  'OUTAGAMIETOWN OF FREEDOM WARDS 1-6': 'OUTAGAMIETOWN OF FREEDOM WARDS 1-8',
#  'OUTAGAMIETOWN OF FREEDOM WARDS 7-8': 'OUTAGAMIETOWN OF FREEDOM WARDS 1-8',
#  'OUTAGAMIETOWN OF GRAND CHUTE WARD 11': 'OUTAGAMIETOWN OF GRAND CHUTE WARDS 11-14',
#  'OUTAGAMIETOWN OF GRAND CHUTE WARD 14': 'OUTAGAMIETOWN OF GRAND CHUTE WARDS 11-14',
#  'OUTAGAMIETOWN OF GRAND CHUTE WARD 15': 'OUTAGAMIETOWN OF GRAND CHUTE WARDS 15-17',
#  'OUTAGAMIETOWN OF GRAND CHUTE WARD 16': 'OUTAGAMIETOWN OF GRAND CHUTE WARDS 11-14',
#  'OUTAGAMIETOWN OF GRAND CHUTE WARD 17': 'OUTAGAMIETOWN OF GRAND CHUTE WARDS 15-17',
#  'OUTAGAMIETOWN OF GRAND CHUTE WARD 4': 'OUTAGAMIETOWN OF GRAND CHUTE WARDS 11-14',
#  'OUTAGAMIETOWN OF GRAND CHUTE WARDS 12-13': 'OUTAGAMIETOWN OF GRAND CHUTE WARDS 11-14',
#  'OUTAGAMIETOWN OF HORTONIA WARD 1': 'OUTAGAMIETOWN OF HORTONIA WARDS 1-2',
#  'OUTAGAMIETOWN OF HORTONIA WARD 2': 'OUTAGAMIETOWN OF HORTONIA WARDS 1-2',
#  'OUTAGAMIETOWN OF KAUKAUNA WARD 1': 'OUTAGAMIETOWN OF KAUKAUNA WARDS 1-3',
#  'OUTAGAMIETOWN OF KAUKAUNA WARD 2': 'OUTAGAMIETOWN OF KAUKAUNA WARDS 1-3',
#  'OUTAGAMIETOWN OF KAUKAUNA WARD 3': 'OUTAGAMIETOWN OF KAUKAUNA WARDS 1-3',
#  'OUTAGAMIETOWN OF ONEIDA WARD 6': 'OUTAGAMIETOWN OF ONEIDA WARDS 1-6',
#  'OUTAGAMIETOWN OF ONEIDA WARDS 1-5': 'OUTAGAMIETOWN OF ONEIDA WARDS 1-6',
#  'OUTAGAMIETOWN OF VANDENBROEK WARD 2': 'OUTAGAMIETOWN OF VANDENBROEK WARDS 1-3',
#  'OUTAGAMIETOWN OF VANDENBROEK WARDS 1,3': 'OUTAGAMIETOWN OF VANDENBROEK WARDS 1-3',
#  'OUTAGAMIEVILLAGE OF COMBINED LOCKS WARD 5': 'OUTAGAMIEVILLAGE OF COMBINED LOCKS WARDS 1-5',
#  'OUTAGAMIEVILLAGE OF HARRISON WARD 1': 'OUTAGAMIEVILLAGE OF HARRISON WARDS 1-2',
#  'OUTAGAMIEVILLAGE OF HARRISON WARD 2': 'OUTAGAMIEVILLAGE OF HARRISON WARDS 1-2',
#  'OUTAGAMIEVILLAGE OF KIMBERLY WARD 1-6': 'OUTAGAMIEVILLAGE OF KIMBERLY WARD 1-9',
#  'OUTAGAMIEVILLAGE OF KIMBERLY WARD 7-8': 'OUTAGAMIEVILLAGE OF KIMBERLY WARD 1-9',
#  'OUTAGAMIEVILLAGE OF KIMBERLY WARD 9': 'OUTAGAMIEVILLAGE OF KIMBERLY WARD 1-9',
#  'OUTAGAMIEVILLAGE OF LITTLE CHUTE WARDS 4-5': 'OUTAGAMIEVILLAGE OF LITTLE CHUTE WARD 7',
#  'OUTAGAMIEVILLAGE OF LITTLE CHUTE WARDS 6,12': 'OUTAGAMIEVILLAGE OF LITTLE CHUTE WARD 7',
#  'OZAUKEECITY OF MEQUON WARDS 5-7': 'OZAUKEECITY OF MEQUON WARDS 5,7B',
#  'OZAUKEEVILLAGE OF GRAFTON WARD 1-2': 'OZAUKEEVILLAGE OF GRAFTON WARDS 1-2',
#  'OZAUKEEVILLAGE OF GRAFTON WARD 11-12': 'OZAUKEEVILLAGE OF GRAFTON WARDS 11-12',
#  'OZAUKEEVILLAGE OF GRAFTON WARD 13-14': 'OZAUKEEVILLAGE OF GRAFTON WARDS 13-14',
#  'OZAUKEEVILLAGE OF GRAFTON WARD 3-4': 'OZAUKEEVILLAGE OF GRAFTON WARDS 3-4',
#  'OZAUKEEVILLAGE OF GRAFTON WARD 5-6': 'OZAUKEEVILLAGE OF GRAFTON WARDS 5-6',
#  'OZAUKEEVILLAGE OF GRAFTON WARD 7-8': 'OZAUKEEVILLAGE OF GRAFTON WARDS 7-8',
#  'OZAUKEEVILLAGE OF GRAFTON WARD 9-10': 'OZAUKEEVILLAGE OF GRAFTON WARDS 9-10',
#  'PIERCETOWN OF ELLSWORTH WARDS 1-2': 'PIERCETOWN OF ELLSWORTH WARD 1-2',
#  'POLKTOWN OF FARMINGTON WARD 1-2': 'POLKTOWN OF FARMINGTON WARDS 1-2',
#  'POLKVILLAGE OF TURTLE LAKE WARDS 2A,2B': 'POLKVILLAGE OF TURTLE LAKE WARD 2A',
#  'PORTAGECITY OF STEVENS POINT WARD 10': 'PORTAGECITY OF STEVENS POINT WARDS 10-12',
#  'PORTAGECITY OF STEVENS POINT WARD 11': 'PORTAGECITY OF STEVENS POINT WARDS 10-12',
#  'PORTAGECITY OF STEVENS POINT WARD 12': 'PORTAGECITY OF STEVENS POINT WARDS 10-12',
#  'PORTAGECITY OF STEVENS POINT WARD 13': 'PORTAGECITY OF STEVENS POINT WARDS 13-15',
#  'PORTAGECITY OF STEVENS POINT WARD 21': 'PORTAGECITY OF STEVENS POINT WARDS 19-21',
#  'PORTAGECITY OF STEVENS POINT WARD 27': 'PORTAGECITY OF STEVENS POINT WARDS 25-27',
#  'PORTAGECITY OF STEVENS POINT WARD 30': 'PORTAGECITY OF STEVENS POINT WARDS 28-30',
#  'PORTAGECITY OF STEVENS POINT WARD 6': 'PORTAGECITY OF STEVENS POINT WARDS 4-6',
#  'PORTAGECITY OF STEVENS POINT WARD 9': 'PORTAGECITY OF STEVENS POINT WARDS 7-9',
#  'PORTAGECITY OF STEVENS POINT WARDS 16-18,37,39': 'PORTAGECITY OF STEVENS POINT WARDS 16-18',
#  'PORTAGECITY OF STEVENS POINT WARDS 19-20,36,38,41': 'PORTAGECITY OF STEVENS POINT WARDS 36,38,41',
#  'PORTAGECITY OF STEVENS POINT WARDS 22-24,35,40,43': 'PORTAGECITY OF STEVENS POINT WARDS 35,40,43',
#  'PORTAGECITY OF STEVENS POINT WARDS 4-5': 'PORTAGECITY OF STEVENS POINT WARDS 4-6',
#  'PORTAGECITY OF STEVENS POINT WARDS 7-8': 'PORTAGECITY OF STEVENS POINT WARDS 7-9',
#  'PORTAGETOWN OF AMHERST WARD 1': 'PORTAGETOWN OF AMHERST WARDS 1-2',
#  'PORTAGETOWN OF AMHERST WARD 2': 'PORTAGETOWN OF AMHERST WARDS 1-2',
#  'PORTAGETOWN OF BUENA VISTA WARD 1': 'PORTAGETOWN OF BUENA VISTA WARDS 1-2',
#  'PORTAGETOWN OF BUENA VISTA WARD 2': 'PORTAGETOWN OF BUENA VISTA WARDS 1-2',
#  'PORTAGETOWN OF CARSON WARD 1-2': 'PORTAGETOWN OF CARSON WARDS 1-2',
#  'PORTAGETOWN OF GRANT WARD 1-4': 'PORTAGETOWN OF GRANT WARDS 1-2,4',
#  'PORTAGETOWN OF HULL WARD 8': 'PORTAGETOWN OF HULL WARDS 6-8',
#  'PORTAGETOWN OF LANARK WARD 1': 'PORTAGETOWN OF LANARK WARDS 1-2',
#  'PORTAGETOWN OF LANARK WARD 2': 'PORTAGETOWN OF LANARK WARDS 1-2',
#  'PORTAGETOWN OF LINWOOD WARD 1-2': 'PORTAGETOWN OF LINWOOD WARDS 1-2',
#  'PORTAGETOWN OF PINE GROVE WARD 1-2': 'PORTAGETOWN OF PINE GROVE WARDS 1-2',
#  'PORTAGETOWN OF SHARON WARD 1-3': 'PORTAGETOWN OF SHARON WARDS 1-3',
#  'PORTAGETOWN OF STOCKTON WARDS 1-3': 'PORTAGETOWN OF STOCKTON WARD 1-5',
#  'PORTAGETOWN OF STOCKTON WARDS 4-5': 'PORTAGETOWN OF STOCKTON WARD 1-5',
#  'PORTAGEVILLAGE OF PLOVER WARD 1': 'PORTAGEVILLAGE OF PLOVER WARD 1-3',
#  'PORTAGEVILLAGE OF PLOVER WARD 6': 'PORTAGEVILLAGE OF PLOVER WARD 4-6',
#  'PORTAGEVILLAGE OF PLOVER WARD 7': 'PORTAGEVILLAGE OF PLOVER WARD 7-9',
#  'PORTAGEVILLAGE OF PLOVER WARDS 2-3': 'PORTAGEVILLAGE OF PLOVER WARD 1-3',
#  'PORTAGEVILLAGE OF PLOVER WARDS 4-5': 'PORTAGEVILLAGE OF PLOVER WARD 4-6',
#  'PORTAGEVILLAGE OF PLOVER WARDS 8-9': 'PORTAGEVILLAGE OF PLOVER WARD 7-9',
#  'PRICETOWN OF WORCESTER WARD 1-3': 'PRICETOWN OF WORCESTER WARDS 1-3',
#  'RACINETOWN OF NORWAY WARD 1-11': 'RACINETOWN OF NORWAY WARDS 1-11',
#  'RACINEVILLAGE OF MOUNT PLEASANT WARDS 1,17-18,20,23': 'RACINEVILLAGE OF MOUNT PLEASANT WARDS 1,17,20',
#  'RACINEVILLAGE OF WATERFORD WARDS 1-7': 'RACINEVILLAGE OF WATERFORD WARD 1-7',
#  'ROCKCITY OF EVANSVILLE WARD 1-10': 'ROCKCITY OF EVANSVILLE WARDS 1-10',
#  'ROCKCITY OF MILTON WARDS 1-8': 'ROCKCITY OF MILTON WARDS 1-12',
#  'ROCKCITY OF MILTON WARDS 9-12': 'ROCKCITY OF MILTON WARDS 1-12',
#  'SAUKCITY OF BARABOO WARD 1': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 10': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 11': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 12': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 13': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 14': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 2': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 3': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 4': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 5': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 6': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 7': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 8': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF BARABOO WARD 9': 'SAUKCITY OF BARABOO WARD 1-14',
#  'SAUKCITY OF REEDSBURG WARD 1-3': 'SAUKCITY OF REEDSBURG WARDS 1-3,13',
#  'SAUKCITY OF REEDSBURG WARD 10-12': 'SAUKCITY OF REEDSBURG WARDS 10-12',
#  'SAUKCITY OF REEDSBURG WARD 13': 'SAUKCITY OF REEDSBURG WARDS 1-3,13',
#  'SAUKCITY OF REEDSBURG WARD 14': 'SAUKCITY OF REEDSBURG WARDS 4,6,14',
#  'SAUKCITY OF REEDSBURG WARD 4,6': 'SAUKCITY OF REEDSBURG WARDS 4,6,14',
#  'SAUKCITY OF REEDSBURG WARD 5': 'SAUKCITY OF REEDSBURG WARDS 5,7-9',
#  'SAUKCITY OF REEDSBURG WARD 7-9': 'SAUKCITY OF REEDSBURG WARDS 5,7-9',
#  'SAUKTOWN OF BARABOO WARD 1': 'SAUKTOWN OF BARABOO WARDS 1-4',
#  'SAUKTOWN OF BARABOO WARD 2': 'SAUKTOWN OF BARABOO WARDS 1-4',
#  'SAUKTOWN OF BARABOO WARD 3': 'SAUKTOWN OF BARABOO WARDS 1-4',
#  'SAUKTOWN OF BARABOO WARD 4': 'SAUKTOWN OF BARABOO WARDS 1-4',
#  'SAUKTOWN OF DELLONA WARD 1-2': 'SAUKTOWN OF DELLONA WARDS 1-2',
#  'SAUKTOWN OF DELTON WARD 1': 'SAUKTOWN OF DELTON WARDS 1-4',
#  'SAUKTOWN OF DELTON WARD 2': 'SAUKTOWN OF DELTON WARDS 1-4',
#  'SAUKTOWN OF DELTON WARD 3': 'SAUKTOWN OF DELTON WARDS 1-4',
#  'SAUKTOWN OF DELTON WARD 4': 'SAUKTOWN OF DELTON WARDS 1-4',
#  'SAUKTOWN OF EXCELSIOR WARD 1-2': 'SAUKTOWN OF EXCELSIOR WARDS 1-3',
#  'SAUKTOWN OF EXCELSIOR WARD 3': 'SAUKTOWN OF EXCELSIOR WARDS 1-3',
#  'SAUKTOWN OF FAIRFIELD WARD 1': 'SAUKTOWN OF FAIRFIELD WARDS 1-2',
#  'TAYLORTOWN OF HAMMEL WARD 2': 'TAYLORTOWN OF HAMMEL WARD 1-2',
#  'TAYLORTOWN OF MEDFORD WARD 1': 'TAYLORTOWN OF MEDFORD WARD 1-3',
#  'TAYLORTOWN OF MEDFORD WARD 2': 'TAYLORTOWN OF MEDFORD WARD 1-3',
#  'TAYLORTOWN OF MEDFORD WARD 3': 'TAYLORTOWN OF MEDFORD WARD 1-3',
#  'TAYLORTOWN OF RIB LAKE WARD 1': 'TAYLORTOWN OF RIB LAKE WARD 1-2',
#  'TAYLORTOWN OF RIB LAKE WARD 2': 'TAYLORTOWN OF RIB LAKE WARD 1-2',
#  'TREMPEALEAUTOWN OF ETTRICK WARD 1-2': 'TREMPEALEAUTOWN OF ETTRICK WARDS 1-2',
#  'TREMPEALEAUTOWN OF GALE WARD 1': 'TREMPEALEAUTOWN OF GALE WARDS 1-3',
#  'TREMPEALEAUTOWN OF GALE WARD 2': 'TREMPEALEAUTOWN OF GALE WARDS 1-3',
#  'TREMPEALEAUTOWN OF GALE WARD 3': 'TREMPEALEAUTOWN OF GALE WARDS 1-3',
#  'WALWORTHCITY OF DELAVAN WARDS 1-5,15': 'WALWORTHCITY OF DELAVAN WARDS 1-14',
#  'WALWORTHCITY OF DELAVAN WARDS 6-10': 'WALWORTHCITY OF DELAVAN WARDS 1-14',
#  'WALWORTHCITY OF ELKHORN WARD 1,5,7': 'WALWORTHCITY OF ELKHORN WARDS 1-7',
#  'WALWORTHCITY OF LAKE GENEVA WARDS 1-2': 'WALWORTHCITY OF LAKE GENEVA WARDS 3-6,10',
#  'WALWORTHCITY OF LAKE GENEVA WARDS 3-4': 'WALWORTHCITY OF LAKE GENEVA WARDS 3-6,10',
#  'WALWORTHCITY OF LAKE GENEVA WARDS 7-9,11-14': 'WALWORTHCITY OF LAKE GENEVA WARDS 1-2,7-9,11-14',
#  'WALWORTHTOWN OF SPRING PRAIRIE WARD 1-4': 'WALWORTHTOWN OF SPRING PRAIRIE WARDS 1-4',
#  'WALWORTHTOWN OF WALWORTH WARD 1-3': 'WALWORTHTOWN OF WALWORTH WARDS 1-3',
#  'WASHINGTONCITY OF HARTFORD WARDS 11-14,21-22': 'WASHINGTONCITY OF HARTFORD WARDS 11-14,21-22,26-27',
#  'WASHINGTONCITY OF HARTFORD WARDS 6-10,15-17,20,23-25': 'WASHINGTONCITY OF HARTFORD WARDS 6,9-10,15-17,20,23-25,28',
#  'WASHINGTONCITY OF WEST BEND WARD 1-3': 'WASHINGTONCITY OF WEST BEND WARDS 1-3',
#  'WASHINGTONCITY OF WEST BEND WARD 15-19,25,27': 'WASHINGTONCITY OF WEST BEND WARDS 15-19',
#  'WASHINGTONCITY OF WEST BEND WARD 20-22': 'WASHINGTONCITY OF WEST BEND WARDS 20-22',
#  'WASHINGTONCITY OF WEST BEND WARD 23-24,26': 'WASHINGTONCITY OF WEST BEND WARDS 23-24,26',
#  'WASHINGTONCITY OF WEST BEND WARD 4-6': 'WASHINGTONCITY OF WEST BEND WARDS 4-6',
#  'WASHINGTONCITY OF WEST BEND WARD 7-8': 'WASHINGTONCITY OF WEST BEND WARDS 7-8',
#  'WASHINGTONTOWN OF TRENTON WARDS 1-8': 'WASHINGTONTOWN OF TRENTON WARDS 1-2,8',
#  'WASHINGTONTOWN OF WEST BEND WARD 1-8': 'WASHINGTONTOWN OF WEST BEND WARDS 1-8',
#  'WASHINGTONVILLAGE OF JACKSON WARD 1-10': 'WASHINGTONVILLAGE OF JACKSON WARD 10',
#  'WASHINGTONVILLAGE OF KEWASKUM WARD 1-5,7': 'WASHINGTONVILLAGE OF KEWASKUM WARDS 1-5,7',
#  'WASHINGTONVILLAGE OF RICHFIELD WARD 1-2': 'WASHINGTONVILLAGE OF RICHFIELD WARDS 1-2',
#  'WASHINGTONVILLAGE OF RICHFIELD WARD 3-4': 'WASHINGTONVILLAGE OF RICHFIELD WARD 3',
#  'WASHINGTONVILLAGE OF RICHFIELD WARD 5-6': 'WASHINGTONVILLAGE OF RICHFIELD WARDS 5-6',
#  'WASHINGTONVILLAGE OF RICHFIELD WARD 7-9': 'WASHINGTONVILLAGE OF RICHFIELD WARDS 7-9',
#  'WAUKESHACITY OF MUSKEGO WARD 13': 'WAUKESHACITY OF MUSKEGO WARD 13-14',
#  'WAUKESHACITY OF MUSKEGO WARD 14': 'WAUKESHACITY OF MUSKEGO WARD 13-14',
#  'WAUKESHACITY OF MUSKEGO WARD 6,8': 'WAUKESHACITY OF MUSKEGO WARD 6-8',
#  'WAUKESHACITY OF MUSKEGO WARD 7': 'WAUKESHACITY OF MUSKEGO WARD 6-8',
#  'WAUKESHACITY OF PEWAUKEE WARD 1-2': 'WAUKESHACITY OF PEWAUKEE WARDS 1-4',
#  'WAUKESHACITY OF PEWAUKEE WARD 3-4': 'WAUKESHACITY OF PEWAUKEE WARDS 1-4',
#  'WAUKESHACITY OF PEWAUKEE WARD 5-7': 'WAUKESHACITY OF PEWAUKEE WARDS 5-7',
#  'WAUKESHACITY OF PEWAUKEE WARD 8': 'WAUKESHACITY OF PEWAUKEE WARDS 8-10',
#  'WAUKESHACITY OF PEWAUKEE WARD 9-10': 'WAUKESHACITY OF PEWAUKEE WARDS 8-10',
#  'WAUKESHATOWN OF BROOKFIELD WARDS 3-4': 'WAUKESHATOWN OF BROOKFIELD WARDS 1,3-4,10',
#  'WAUKESHATOWN OF BROOKFIELD WARDS 9-10': 'WAUKESHATOWN OF BROOKFIELD WARD 9',
#  'WAUKESHATOWN OF EAGLE WARD 1-4': 'WAUKESHATOWN OF EAGLE WARDS 1-4',
#  'WAUKESHATOWN OF GENESEE WARD 1,6,9': 'WAUKESHATOWN OF GENESEE WARDS 1,3,5,9',
#  'WAUKESHATOWN OF GENESEE WARD 2,5': 'WAUKESHATOWN OF GENESEE WARDS 6-8',
#  'WAUKESHATOWN OF GENESEE WARD 3,10': 'WAUKESHATOWN OF GENESEE WARDS 2,4,10',
#  'WAUKESHATOWN OF GENESEE WARD 4,7-8': 'WAUKESHATOWN OF GENESEE WARDS 6-8',
#  'WAUPACACITY OF CLINTONVILLE WARD 3': 'WAUPACACITY OF CLINTONVILLE WARD 8',
#  'WAUPACACITY OF CLINTONVILLE WARD 4': 'WAUPACACITY OF CLINTONVILLE WARD 8',
#  'WAUPACACITY OF CLINTONVILLE WARD 5': 'WAUPACACITY OF CLINTONVILLE WARD 8',
#  'WAUPACACITY OF CLINTONVILLE WARDS 6-7': 'WAUPACACITY OF CLINTONVILLE WARD 1-7',
#  'WAUPACACITY OF WAUPACA WARD 1': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WAUPACACITY OF WAUPACA WARD 12': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WAUPACACITY OF WAUPACA WARD 3': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WAUPACACITY OF WAUPACA WARD 4': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WAUPACACITY OF WAUPACA WARD 6': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WAUPACACITY OF WAUPACA WARD 8': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WAUPACACITY OF WAUPACA WARD 9': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WAUPACACITY OF WAUPACA WARDS 2,7,11': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WAUPACACITY OF WAUPACA WARDS 5,10': 'WAUPACACITY OF WAUPACA WARDS 1-12',
#  'WINNEBAGOCITY OF MENASHA WARDS 1-2,4,7': 'WINNEBAGOCITY OF MENASHA WARDS 1A-2,4,7',
#  'WINNEBAGOCITY OF MENASHA WARDS 5-6,8-9,23-29,31-35,38': 'WINNEBAGOCITY OF MENASHA WARDS 5A-6,8-9,23-29,31-35,38',
#  'WINNEBAGOCITY OF OMRO WARDS 1-8': 'WINNEBAGOCITY OF OMRO WARD 1-8',
#  'WINNEBAGOTOWN OF MENASHA WARD 11-13': 'WINNEBAGOTOWN OF MENASHA WARDS 11-13',
#  'WINNEBAGOTOWN OF MENASHA WARD 8-10': 'WINNEBAGOTOWN OF MENASHA WARDS 8-10',
#  'WINNEBAGOTOWN OF OSHKOSH WARDS 1A-5': 'WINNEBAGOTOWN OF OSHKOSH WARDS 1A,2-5',
#  'WOODCITY OF MARSHFIELD WARD 1,11': 'WOODCITY OF MARSHFIELD WARDS 1,11',
#  'WOODCITY OF MARSHFIELD WARD 3,13': 'WOODCITY OF MARSHFIELD WARDS 3,13',
#  'WOODCITY OF MARSHFIELD WARD 4,14': 'WOODCITY OF MARSHFIELD WARDS 4,14',
#  'WOODCITY OF MARSHFIELD WARD 5,15': 'WOODCITY OF MARSHFIELD WARDS 5,15',
#  'WOODCITY OF MARSHFIELD WARD 8,18,23': 'WOODCITY OF MARSHFIELD WARDS 8,19,22-23',
#  'WOODCITY OF MARSHFIELD WARD 9,19,22': 'WOODCITY OF MARSHFIELD WARDS 8,19,22-23',
#  'WOODCITY OF MARSHFIELD WARDS 6,16,25-26': 'WOODCITY OF MARSHFIELD WARDS 6,17,25-26',
#  'WOODCITY OF MARSHFIELD WARDS 7,17,27': 'WOODCITY OF MARSHFIELD WARDS 7,16,27'}

# %%
# Checking any suspicious precinct, county
suspicious_precincts = pri_combined_df[
    pri_combined_df["precinct"].isna() |
    pri_combined_df["precinct"].str.strip().str.upper().str.contains(r"\w*TOTAL\w*", na=False) |
    pri_combined_df["precinct"].str.strip().str.upper().isin(["NONE", "NAN"]) |
    pri_combined_df["county"].isna() |
    pri_combined_df["county"].str.strip().str.upper().str.contains(r"\w*TOTAL\w*", na=False) |
    pri_combined_df["county"].str.strip().str.upper().isin(["NONE", "NAN"])
]

# %%
# Select only the relevant columns
primary_data = pri_combined_df[["precinct", "party", "candidate", "votes"]]

primary_data
# Out:
#                                           precinct party  \
# 0                     ADAMSTOWN OF ADAMS WARDS 1-3   REP
# 1                     ADAMSTOWN OF ADAMS WARDS 1-3   REP
# 2                     ADAMSTOWN OF ADAMS WARDS 1-3   REP
# 3                     ADAMSTOWN OF ADAMS WARDS 1-3   REP
# 4                     ADAMSTOWN OF ADAMS WARDS 1-3   REP
# ...                                            ...   ...
# 81475  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   DEM
# 81476  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   DEM
# 81477  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   DEM
# 81478  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   DEM
# 81479  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   DEM
#
#                                  candidate  votes
# 0                              Marco Rubio      3
# 1                               Ben Carson      0
# 2                                Rand Paul      2
# 3                            Mike Huckabee      1
# 4                              Jim Gilmore      0
# ...                                    ...    ...
# 81475                      Martin O'Malley      3
# 81476                       Bernie Sanders    388
# 81477              Uninstructed Delegation      1
# 81478  Roque Rocky De La Fuente (Write-In)      0
# 81479                           Scattering      0
#
# [81480 rows x 4 columns]

# %%
# Viewing candidate data
primary_data["candidate"].value_counts(dropna=False)
# Out:
# candidate
# Scattering                             7760
# Uninstructed Delegation                7760
# Marco Rubio                            3880
# Jeb Bush                               3880
# Bernie Sanders                         3880
# Martin O'Malley                        3880
# Hillary Clinton                        3880
# Victor Williams (Write-In)             3880
# Ted Cruz                               3880
# John R. Kasich                         3880
# Ben Carson                             3880
# Carly Fiorina                          3880
# Rick Santorum                          3880
# Donald J. Trump                        3880
# Chris Christie                         3880
# Jim Gilmore                            3880
# Mike Huckabee                          3880
# Rand Paul                              3880
# Roque Rocky De La Fuente (Write-In)    3880
# Name: count, dtype: int64

# %%
# Cleaning Candidates

# Turning all primary data to uppercase
primary_data["candidate"] = primary_data["candidate"].astype(str).str.upper()

unwanted_keywords = [
    r"\w*VOTE\w*",
    r"\w*UNCOM\w*",
    r"\w*TOTAL\w*",
    r"\w*ATTERING\w*",
    r"\w*UNINSTRUCTED\w*",
    r"UNCOMMITTED", r"OTHER",r"Total Votes Cast",r"No Preference"
]

pattern = "|".join(unwanted_keywords)

# Assuming candidate column is already string and uppercase
primary_data = primary_data[~primary_data["candidate"].str.upper().str.contains(pattern, regex=True, na=False)]

#fIXING DE LA FUENTE
primary_data.loc[
    (
        primary_data["candidate"].str.contains("rocky.*fuente", case=False, na=False) |
        primary_data["candidate"].str.contains("LA FUENTE", case=False, na=False) |
        primary_data["candidate"].str.contains("\w*Fuque\w*", case=False, na=False)
    ),
    "candidate"
] = "LA FUENTE"

# # Fixing williams
primary_data.loc[
    primary_data["candidate"].str.contains("WILLIAMS", case=False, na=False),
    "candidate"
] = "WILLIAMS"

primary_data.loc[:, "candidate"] = primary_data["candidate"].replace({
    "Donald I. Trump": "Donald J. Trump",
})

# # Fixing the , candidate
# primary_data["candidate"] = (
#     primary_data["candidate"].str.split(",")
#     .str[0]
#     .str.strip()
#     )


# #Selecting only last name
primary_data["candidate"] = primary_data["candidate"].str.split().str[-1]

# # Fixing Christie
# primary_data.loc[
#     primary_data["candidate"].str.contains("CHRISTLE", case=False, na=False),
#     "candidate"
# ] = "CHRISTIE"

# # Fixing KASICH
# primary_data.loc[
#     primary_data["candidate"].str.contains("KAISCH", case=False, na=False),
#     "candidate"
# ] = "CHRISTIE"

# # Fixing O'MALLEY
# primary_data.loc[
#     primary_data["candidate"].str.contains("O'MALLEY", case=False, na=False),
#     "candidate"
# ] = "O'MAILEY"

# # Fixing O'MALLEY
# primary_data.loc[
#     primary_data["candidate"].str.contains("PATAKL", case=False, na=False),
#     "candidate"
# ] = "PATAKI"

# # Fixing O'MALLEY
# primary_data.loc[
#     primary_data["candidate"].str.contains("RUBLO", case=False, na=False),
#     "candidate"
# ] = "RUBIO"

# # Fixing Huckabee
# primary_data.loc[
#     primary_data["candidate"].str.contains("\w*ABEE\w*", case=False, na=False),
#     "candidate"
# ] = "HUCKABEE"

# # Fixing Fiorina
# primary_data.loc[
#     primary_data["candidate"].str.contains("\w*ORINA\W*", case=False, na=False),
#     "candidate"
# ] = "FIORINA"

# # Fixing Gray
# primary_data.loc[
#     primary_data["candidate"].str.contains("GREY", case=False, na=False),
#     "candidate"
# ] = "GRAY"

# # Fixing Wilson
# primary_data.loc[
#     primary_data["candidate"].str.contains("WISON", case=False, na=False),
#     "candidate"
# ] = "WILSON"


# # Fixing separator 
# primary_data["candidate"] = (
#     primary_data["candidate"]
#     .str.split(r"\s*(?:and|/|&|–|-|\+)\s*", n=1, expand=True)[0]
#     .str.strip()
#     .str.upper()
# )

# # Fixing McMullin

# primary_data.loc[
#     (
#         primary_data["candidate"].str.contains("MCMULLIN", case=False, na=False) |
#         primary_data["candidate"].str.contains("EVAN MCMULLEN", case=False, na=False)
#     ),
#     "candidate"
# ] = "MCMULLIN"

# primary_data.loc[
#     primary_data["candidate"].str.contains("De La Fuen", case=False, na=False),
#     "candidate"
# ] = "FUENTE D"

# primary_data.loc[:,"candidate"] = (
#     primary_data["candidate"].str.split().str[0].str.upper()
# )

primary_data["candidate"].value_counts(dropna=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\1590360723.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primary_data["candidate"] = primary_data["candidate"].astype(str).str.upper()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\1590360723.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primary_data["candidate"] = primary_data["candidate"].str.split().str[-1]
# candidate
# RUBIO       3880
# KASICH      3880
# SANDERS     3880
# O'MALLEY    3880
# CLINTON     3880
# WILLIAMS    3880
# CRUZ        3880
# BUSH        3880
# FIORINA     3880
# CARSON      3880
# SANTORUM    3880
# TRUMP       3880
# CHRISTIE    3880
# GILMORE     3880
# HUCKABEE    3880
# PAUL        3880
# FUENTE      3880
# Name: count, dtype: int64

# %%
# Viewing Party
primary_data["party"].value_counts(dropna=False)
# Out:
# party
# REP    50440
# DEM    15520
# Name: count, dtype: int64

# %%
#=====================================
# This function is used to look up party
# for the candidate in the same df
#=====================================
def fill_party_from_data(row, df):
    if pd.notna(row["party"]):
        return row["party"]
    
    # Try to find other rows with the same candidate and known party
    matches = df[(df["candidate"] == row["candidate"]) & (df["party"].notna())]
    if not matches.empty:
        return matches["party"].iloc[0]  # Return the first match's party
    else:
        return None  # Still unknown

#=====================================
# Example usage (uncomment and modify for your workflow)
#=====================================
# Fill party using internal data
# primary_data["party"] = primary_data.apply(
#     lambda row: fill_party_from_data(row, primary_data),
#     axis=1
# )

primary_data["party"].value_counts(dropna=False)
# Out:
# party
# REP    50440
# DEM    15520
# Name: count, dtype: int64

# %%
# Cleaning Party
# Turning all general data party to uppercase
primary_data["party"] = primary_data["party"].astype(str).str.upper()

# primary_data["party"] = primary_data.apply(
#     lambda row: fill_party_from_data(row, primary_data),
#     axis=1
# )
primary_data["party"] = (
    primary_data["party"]
    .replace({
        "REPUBLICAN": "REP",
        "R": "REP",
        "DEMOCRATIC": "DEM",
        "DEMOCRAT":"DEM",
        "DEM": "DEM",
        "D": "DEM",
        "GREEN": "GRN",
        "G": "GREEN",
        "GREEN-RAINBOW":"GRN",
        "LIBERTARIAN": "LIB",
        "LBT": "LIB",
        "L": "LIB",
        "CONSTITUTION": "CON",
        "NP": "IND",
        "NON": "IND",
        "WRI": "IND",
        "WRITE-IN": "IND",
        "ONA": "IND",
        "GEN": "IND",
        "NONE":"UNK"
    })
)
primary_data["party"].value_counts(dropna=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\453441538.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primary_data["party"] = primary_data["party"].astype(str).str.upper()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\453441538.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primary_data["party"] = (
# party
# REP    50440
# DEM    15520
# Name: count, dtype: int64

# %%
primary_data.loc[:,"candidate_column"] = (
    "pri_" +
    primary_data["party"].str.lower() + "_" +
    primary_data["candidate"]
)

# pivot the table
primary_result = primary_data.pivot_table(
    index="precinct",
    columns="candidate_column",
    values="votes",
    aggfunc="sum",  
    fill_value=0
).reset_index()

primary_result
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\2521670330.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   primary_data.loc[:,"candidate_column"] = (
# candidate_column                                precinct  pri_dem_CLINTON  \
# 0                            ADAMSCITY OF ADAMS WARD 1-4              130
# 1                 ADAMSCITY OF WISCONSIN DELLS WARDS 5,9                1
# 2                           ADAMSTOWN OF ADAMS WARDS 1-3               79
# 3                        ADAMSTOWN OF BIG FLATS WARD 1-2               56
# 4                            ADAMSTOWN OF COLBURN WARD 1                6
# ...                                                  ...              ...
# 3574                        WOODVILLAGE OF HEWITT WARD 1               56
# 3575                     WOODVILLAGE OF MILLADORE WARD 1               14
# 3576               WOODVILLAGE OF PORT EDWARDS WARDS 1-3              136
# 3577                       WOODVILLAGE OF RUDOLPH WARD 1               35
# 3578                        WOODVILLAGE OF VESPER WARD 1               29
#
# candidate_column  pri_dem_FUENTE  pri_dem_O'MALLEY  pri_dem_SANDERS  \
# 0                              0                 1              123
# 1                              0                 0                5
# 2                              0                 3               81
# 3                              0                 0               89
# 4                              0                 0               17
# ...                          ...               ...              ...
# 3574                           0                 0               86
# 3575                           0                 0               22
# 3576                           0                 0              167
# 3577                           0                 0               44
# 3578                           0                 0               46
#
# candidate_column  pri_rep_BUSH  pri_rep_CARSON  pri_rep_CHRISTIE  \
# 0                            3               1                 0
# 1                            0               0                 0
# 2                            0               0                 0
# 3                            0               2                 0
# 4                            0               1                 0
# ...                        ...             ...               ...
# 3574                         0               2                 0
# 3575                         0               0                 0
# 3576                         2               6                 0
# 3577                         0               0                 0
# 3578                         0               0                 0
#
# candidate_column  pri_rep_CRUZ  pri_rep_FIORINA  pri_rep_GILMORE  \
# 0                           83                0                0
# 1                            0                0                0
# 2                           86                0                0
# 3                           66                0                0
# 4                           13                0                0
# ...                        ...              ...              ...
# 3574                       114                0                0
# 3575                        31                0                0
# 3576                       175                0                0
# 3577                        57                0                0
# 3578                        69                0                1
#
# candidate_column  pri_rep_HUCKABEE  pri_rep_KASICH  pri_rep_PAUL  \
# 0                                2              16             2
# 1                                0               2             0
# 2                                1              14             2
# 3                                2               6             0
# 4                                1               4             0
# ...                            ...             ...           ...
# 3574                             2              22             0
# 3575                             0               0             0
# 3576                             0              51             0
# 3577                             0               8             0
# 3578                             0               7             0
#
# candidate_column  pri_rep_RUBIO  pri_rep_SANTORUM  pri_rep_TRUMP  \
# 0                             4                 0            140
# 1                             0                 0              4
# 2                             3                 1            164
# 3                             3                 0            117
# 4                             0                 0             37
# ...                         ...               ...            ...
# 3574                          2                 0             87
# 3575                          1                 0             27
# 3576                          2                 0            166
# 3577                          0                 0             31
# 3578                          1                 0             55
#
# candidate_column  pri_rep_WILLIAMS
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# 3574                             0
# 3575                             0
# 3576                             0
# 3577                             0
# 3578                             0
#
# [3579 rows x 18 columns]

# %%
# Process general files
general_df_list = []

for file in general_files:
    try:
        df = pd.read_csv(file)
        
        # Combine precinct as county + precinct
        df["precinct"] = df["county"].astype(str) + df["ward"].astype(str)
        df["precinct"] = df["precinct"].str.upper()
        df["county"] = df["county"].str.upper()

        # Cleaning maybe total precinct
        if 'precinct' in df.columns:
            df['precinct'] = df['precinct'].astype(str)                  
            df = df[df['precinct'].str.upper() != "TOTAL"]               
            df = df[df['precinct'].str.strip().str.upper() != "TOTAL"]   
            df = df[df['precinct'].str.upper() != "NAN"]                
        
        if 'county' in df.columns:
            df['county'] = df['county'].astype(str)                  
            df = df[df['county'].str.upper() != "TOTAL"]               
            df = df[df['county'].str.strip().str.upper() != "TOTAL"]   
            df = df[df['county'].str.upper() != "NAN"]       
            df = df[~df['county'].str.upper().str.contains(r"\w*TOTAL\w*", na=False)]      
            
        # Filtering out only President 
        if 'office' in df.columns:
            df = df[df["office"] == "President"]
        
        # Dropping duplicates value
        df = df.drop_duplicates()
        
        general_df_list.append(df)

    except Exception as e:
        print(f"Error in {file}: {e}")

# Combine all cleaned files
gen_combined_df = pd.concat(general_df_list, ignore_index=True)
# Checking any suspicious precinct
suspicious_precincts = gen_combined_df[
    gen_combined_df["precinct"].str.strip().str.upper().isin(["TOTAL", "NAN"])
]
gen_combined_df
# Out:
#       county                                     ward     office  district  \
# 0      ADAMS                  Town Of Adams Wards 1-3  President       NaN
# 1      ADAMS                  Town Of Adams Wards 1-3  President       NaN
# 2      ADAMS                  Town Of Adams Wards 1-3  President       NaN
# 3      ADAMS                  Town Of Adams Wards 1-3  President       NaN
# 4      ADAMS                  Town Of Adams Wards 1-3  President       NaN
# ...      ...                                      ...        ...       ...
# 61807   WOOD  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
# 61808   WOOD  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
# 61809   WOOD  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
# 61810   WOOD  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
# 61811   WOOD  City Of Wisconsin Rapids Wards 16-23,25  President       NaN
#
#        total votes party                                          candidate  \
# 0              618   REP                 Donald J. Trump & Michael R. Pence
# 1              618   DEM                        Hillary Clinton & Tim Kaine
# 2              618   CON               Darrell L. Castle & Scott N. Bradley
# 3              618   LIB                           Gary Johnson & Bill Weld
# 4              618   WGR                          Jill Stein & Ajamu Baraka
# ...            ...   ...                                                ...
# 61807         2571   IND   Laurence Kotlikoff & Edward E. Leamer (Write-In)
# 61808         2571   IND            Tom Hoefling & Steve Schulin (Write-In)
# 61809         2571   IND                        Joseph Maldonado (Write-In)
# 61810         2571   IND  Emidio Soltysik & Angela Nicole Walker (Write-In)
# 61811         2571   NaN                                         Scattering
#
#        votes                                     precinct
# 0        377                 ADAMSTOWN OF ADAMS WARDS 1-3
# 1        207                 ADAMSTOWN OF ADAMS WARDS 1-3
# 2          3                 ADAMSTOWN OF ADAMS WARDS 1-3
# 3         22                 ADAMSTOWN OF ADAMS WARDS 1-3
# 4          4                 ADAMSTOWN OF ADAMS WARDS 1-3
# ...      ...                                          ...
# 61807      0  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
# 61808      0  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
# 61809      0  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
# 61810      0  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
# 61811      0  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25
#
# [61812 rows x 9 columns]

# %%
gen_combined_df.loc[(
    gen_combined_df["precinct"].str.contains("BARRONVILLAGE OF NEW AUBURN WARD 2", case=False, na=False) |
    gen_combined_df["precinct"].str.contains("BARRONVILLAGE OF NEW AUBURN WARD 3", case=False, na=False)
), "precinct"] = "BARRONVILLAGE OF NEW AUBURN WARDS 2-3"

# %%
# Select only the relevant columns
general_data = gen_combined_df[["precinct", "party", "candidate", "votes"]]

general_data
# Out:
#                                           precinct party  \
# 0                     ADAMSTOWN OF ADAMS WARDS 1-3   REP
# 1                     ADAMSTOWN OF ADAMS WARDS 1-3   DEM
# 2                     ADAMSTOWN OF ADAMS WARDS 1-3   CON
# 3                     ADAMSTOWN OF ADAMS WARDS 1-3   LIB
# 4                     ADAMSTOWN OF ADAMS WARDS 1-3   WGR
# ...                                            ...   ...
# 61807  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   IND
# 61808  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   IND
# 61809  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   IND
# 61810  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   IND
# 61811  WOODCITY OF WISCONSIN RAPIDS WARDS 16-23,25   NaN
#
#                                                candidate  votes
# 0                     Donald J. Trump & Michael R. Pence    377
# 1                            Hillary Clinton & Tim Kaine    207
# 2                   Darrell L. Castle & Scott N. Bradley      3
# 3                               Gary Johnson & Bill Weld     22
# 4                              Jill Stein & Ajamu Baraka      4
# ...                                                  ...    ...
# 61807   Laurence Kotlikoff & Edward E. Leamer (Write-In)      0
# 61808            Tom Hoefling & Steve Schulin (Write-In)      0
# 61809                        Joseph Maldonado (Write-In)      0
# 61810  Emidio Soltysik & Angela Nicole Walker (Write-In)      0
# 61811                                         Scattering      0
#
# [61812 rows x 4 columns]

# %%
# Viewing candidate data
general_data["candidate"] = general_data["candidate"].astype(str).str.upper()
general_data["candidate"].value_counts(dropna=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\1743146100.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["candidate"] = general_data["candidate"].astype(str).str.upper()
# candidate
# DONALD J. TRUMP & MICHAEL R. PENCE                             3636
# MICHAEL A. MATUREN & JUAN MUNOZ (WRITE-IN)                     3636
# EMIDIO SOLTYSIK & ANGELA NICOLE WALKER (WRITE-IN)              3636
# JOSEPH MALDONADO (WRITE-IN)                                    3636
# TOM HOEFLING & STEVE SCHULIN (WRITE-IN)                        3636
# LAURENCE KOTLIKOFF & EDWARD E. LEAMER (WRITE-IN)               3636
# CHRIS KENISTON & DEACON TAYLOR (WRITE-IN)                      3636
# MARSHALL SCHOENKE & JAMES CREIGHTON MITCHELL JR. (WRITE-IN)    3636
# EVAN MCMULLIN & NATHAN JOHNSON (WRITE-IN)                      3636
# HILLARY CLINTON & TIM KAINE                                    3636
# CHERUNDA FOX & ROGER KUSHNER (WRITE-IN)                        3636
# ROCKY ROQUE DE LA FUENTE & MICHAEL STEINBERG                   3636
# MONICA MOOREHEAD & LAMONT LILLY                                3636
# JILL STEIN & AJAMU BARAKA                                      3636
# GARY JOHNSON & BILL WELD                                       3636
# DARRELL L. CASTLE & SCOTT N. BRADLEY                           3636
# SCATTERING                                                     3636
# Name: count, dtype: int64

# %%
# Cleaning Candidates

# Turning all general data to uppercase
general_data["candidate"] = general_data["candidate"].astype(str).str.upper()


unwanted_keywords = [
    r"\w*VOTE\w*",
    r"\w*UNCOM\w*",
    r"\w*TOTAL\w*",
    r"NAN",
    r"UNCERTIFIED",
    r"UNVERIFIED",
    r"NONE OF THE ABOVE",
    r"LBT",
    r"DEM",
    r"REP",
    r"GRN",
    r"NAN",
    r"\w*CANDIDATES\w*",
    "SCATTERING"
]

# Fixing FUENTE
general_data.loc[
    general_data["candidate"].str.contains("\w*FUENTE\w*", case=False, na=False),
    "candidate"
] = "FUENTE"
pattern = "|".join(unwanted_keywords)

# FILTER OUT TRASH WORDS
general_data = general_data[~general_data["candidate"].str.upper().str.contains(pattern, regex=True, na=False)]

# # Fixing Darrell Castle"
# general_data.loc[
#     general_data["candidate"].str.contains("\w*ASTLE\w*", case=False, na=False),
#     "candidate"
# ] = "CASTLE"

general_data.loc[
    general_data["candidate"].str.contains("\w*ATUREN\w*", case=False, na=False),
    "candidate"
] = "MATUREN"

general_data.loc[
    general_data["candidate"].str.contains("\w*OLTYSIK\w*", case=False, na=False),
    "candidate"
] = "SOLTYSIK"

general_data.loc[
    general_data["candidate"].str.contains("\w*MALDONADO\w*", case=False, na=False),
    "candidate"
] = "MALDONADO"

# # Fixing mixed president + vice_president by /
# general_data["candidate"] = (
#     general_data["candidate"].str.split("/")
#     .str[0]
#     .str.strip()
#     )

# #Selecting only last name
# general_data["candidate"] = general_data["candidate"].str.split().str[-1]

# Fixing the & candidate
general_data["candidate"] = (
    general_data["candidate"].str.split("&")
    .str[0]
    .str.strip()
    )




# # Fixing Cubbler
# general_data.loc[
#     ( 
#         general_data["candidate"].str.contains("\w*UBBIER\w*", case=False, na=False)|
#         general_data["candidate"].str.contains("\w*UBLER\w*", case=False, na=False)|
#         general_data["candidate"].str.contains("\w*OBBLER\w*", case=False, na=False),
#     "candidate")
# ] = "CUBBLER"


# Fixing Kotlikoff
general_data.loc[
    general_data["candidate"].str.contains("\w*LIKOFF\w*", case=False, na=False),
    "candidate"
] = "KOTLIKOFF"

# Fixing Valdivia
general_data.loc[
    general_data["candidate"].str.contains("\w*KENISTON\W*", case=False, na=False),
    "candidate"
] = "KENISTON"

# Fixing HOEFLING
general_data.loc[
    general_data["candidate"].str.contains("\w*HOEFFLING", case=False, na=False),
    "candidate"
] = "HOEFLING"

general_data.loc[
    general_data["candidate"].str.contains("\w*SCHOENKE", case=False, na=False),
    "candidate"
] = "SCHOENKE"


# Fixing McMullin
general_data.loc[
    general_data["candidate"].str.contains("MCMULLIN", case=False, na=False) ,
    "candidate"
] = "MCMULLIN"

general_data.loc[
    general_data["candidate"].str.contains("FOX", case=False, na=False) ,
    "candidate"
] = "FOX"

# Fixing LASTNAME + First name Initial
# general_data.loc[:,"candidate"] = (
#     general_data["candidate"].str.split().str[0].str.upper()
# )


# #Selecting only last name
general_data["candidate"] = general_data["candidate"].str.split().str[-1]

general_data["candidate"].value_counts(dropna=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\248022595.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["candidate"] = general_data["candidate"].astype(str).str.upper()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\248022595.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["candidate"] = (
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\248022595.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["candidate"] = general_data["candidate"].str.split().str[-1]
# candidate
# TRUMP        3636
# CLINTON      3636
# CASTLE       3636
# JOHNSON      3636
# STEIN        3636
# MOOREHEAD    3636
# FUENTE       3636
# FOX          3636
# MCMULLIN     3636
# MATUREN      3636
# SCHOENKE     3636
# KENISTON     3636
# KOTLIKOFF    3636
# HOEFLING     3636
# MALDONADO    3636
# SOLTYSIK     3636
# Name: count, dtype: int64

# %%
# Viewing Party
general_data["party"].value_counts(dropna=False)
# Out:
# party
# IND    39996
# REP     3636
# DEM     3636
# CON     3636
# LIB     3636
# WGR     3636
# Name: count, dtype: int64

# %%
#=====================================
# This function is used to look up party
# for the candidate in the same df
#=====================================
def fill_party_from_data(row, df):
    if pd.notna(row["party"]):
        return row["party"]
    
    # Try to find other rows with the same candidate and known party
    matches = df[(df["candidate"] == row["candidate"]) & (df["party"].notna())]
    if not matches.empty:
        return matches["party"].iloc[0]  # Return the first match's party
    else:
        return None  # Still unknown
    

#=====================================
# Function to update the master candidate-party CSV
#=====================================
def update_master_candidate_party(df, master_path):
    # Read the existing master file
    master_df = pd.read_csv(master_path)

    # Filter and combine only known party entries (exclude 'UNK')
    new_data = (
        df[["candidate", "party"]]
        .dropna()
        .query('party != "UNK"')
        .drop_duplicates()
    )

    # Merge with master and remove duplicates by candidate
    updated_master = pd.concat([master_df, new_data]).drop_duplicates(subset="candidate")

    # Save updated version
    updated_master.to_csv(master_path, index=False)


#=====================================
# Function to update the master candidate-party CSV
#=====================================
def update_master_candidate_party(df, master_path):
    # Read the existing master file
    master_df = pd.read_csv(master_path)

    # Filter and combine only known party entries (exclude 'UNK')
    new_data = (
        df[["candidate", "party"]]
        .dropna()
        .query('party != "UNK"')
        .drop_duplicates()
    )

    # Merge with master and remove duplicates by candidate
    updated_master = pd.concat([master_df, new_data]).drop_duplicates(subset="candidate")

    # Save updated version
    updated_master.to_csv(master_path, index=False)


#=====================================
# Example usage (uncomment and modify for your workflow)
#=====================================
# Fill party using internal data
# general_data["party"] = general_data.apply(
#     lambda row: fill_party_from_data(row, general_data),
#     axis=1
# )

# # Fill remaining party using general master CSV
# master_party_df = pd.read_csv(r"C:\Huy Phan\College\VoterTurnout\data\cleaned_data\gen_can_party.csv") # USE YOUR OWN ADDRESS
# general_data = fill_party_from_master(general_data, master_party_df)
general_data["party"].value_counts(dropna=False)
# Out:
# party
# IND    39996
# REP     3636
# DEM     3636
# CON     3636
# LIB     3636
# WGR     3636
# Name: count, dtype: int64

# %%
# Cleaning Party
# Turning all general data party to uppercase
general_data["party"] = general_data["party"].astype(str).str.upper()

general_data["party"] = (
    general_data["party"]
    .replace({
        "REPUBLICAN": "REP",
        "R": "REP",
        "DEMOCRATIC": "DEM",
        "DEMOCRAT":"DEM",
        "DEM": "DEM",
        "D": "DEM",
        "GREEN": "GRN",
        "G": "GRN",
        "WGR":"GRN",
        "GREEN AND RAINBOW":"GRN",
        "GREEN-RAINBOW":"GRN",
        "LIBERTARIAN": "LIB",
        "LIBERTARIN":"LIB",
        "LPN":"LIB",
        "LBT": "LIB",
        "L": "LIB",
        "IAP":"CON",
        "CONSTITUTION": "CON",
        "AMERICAN DELTA":"AMD",
        "PROHIBITION":"PRO",
        "NP": "IND",
        "NON": "IND",
        "WRI": "IND",
        "WRITE-IN": "IND",
        "ONA": "IND",
        "GEN": "IND",
        "NONE":"UNK",
        "NPA":"IND",
        "UST":"CON",
        "NPP":"IND",
        "(WRITE-IN)":"IND"
    })
)

general_data["party"].value_counts(dropna=False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\4120040037.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["party"] = general_data["party"].astype(str).str.upper()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\4120040037.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["party"] = (
# party
# IND    39996
# REP     3636
# DEM     3636
# CON     3636
# LIB     3636
# GRN     3636
# Name: count, dtype: int64

# %%
# UPDATE MASTER FILE, CAREFUL
update_master_candidate_party(general_data, r"C:\Huy Phan\College\VoterTurnout\data\cleaned_data\gen_can_party.csv")

# %%
general_data["candidate_column"] = (
    "gen_" +
    general_data["party"].str.lower() + "_" +
    general_data["candidate"].str.split().str[-1].str.upper()
)

# pivot the table
general_result = general_data.pivot_table(
    index="precinct",
    columns="candidate_column",
    values="votes",
    aggfunc="sum",  
    fill_value=0
).reset_index()

general_result
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_33704\1829951435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_data["candidate_column"] = (
# candidate_column                                precinct  gen_con_CASTLE  \
# 0                            ADAMSCITY OF ADAMS WARD 1-4               6
# 1                 ADAMSCITY OF WISCONSIN DELLS WARDS 5,9               0
# 2                           ADAMSTOWN OF ADAMS WARDS 1-3               3
# 3                        ADAMSTOWN OF BIG FLATS WARD 1-2               4
# 4                            ADAMSTOWN OF COLBURN WARD 1               0
# ...                                                  ...             ...
# 3630                        WOODVILLAGE OF HEWITT WARD 1               1
# 3631                     WOODVILLAGE OF MILLADORE WARD 1               2
# 3632               WOODVILLAGE OF PORT EDWARDS WARDS 1-3               7
# 3633                       WOODVILLAGE OF RUDOLPH WARD 1               2
# 3634                        WOODVILLAGE OF VESPER WARD 1               2
#
# candidate_column  gen_dem_CLINTON  gen_grn_STEIN  gen_ind_FOX  gen_ind_FUENTE  \
# 0                             329              6            0               1
# 1                               7              0            0               0
# 2                             207              4            0               0
# 3                             169              4            0               0
# 4                              42              2            0               0
# ...                           ...            ...          ...             ...
# 3630                          181              3            0               0
# 3631                           47              3            0               0
# 3632                          389              9            0               1
# 3633                          101              2            0               1
# 3634                           89              2            0               0
#
# candidate_column  gen_ind_HOEFLING  gen_ind_KENISTON  gen_ind_KOTLIKOFF  \
# 0                                0                 0                  0
# 1                                0                 0                  0
# 2                                0                 0                  0
# 3                                0                 0                  0
# 4                                0                 0                  0
# ...                            ...               ...                ...
# 3630                             0                 0                  0
# 3631                             0                 0                  0
# 3632                             0                 0                  0
# 3633                             0                 0                  0
# 3634                             0                 0                  0
#
# candidate_column  gen_ind_MALDONADO  gen_ind_MATUREN  gen_ind_MCMULLIN  \
# 0                                 0                0                 4
# 1                                 0                0                 0
# 2                                 0                0                 3
# 3                                 0                0                 0
# 4                                 0                0                 0
# ...                             ...              ...               ...
# 3630                              0                0                 1
# 3631                              0                0                 0
# 3632                              0                0                 4
# 3633                              0                0                 0
# 3634                              0                0                 0
#
# candidate_column  gen_ind_MOOREHEAD  gen_ind_SCHOENKE  gen_ind_SOLTYSIK  \
# 0                                 2                 0                 0
# 1                                 0                 0                 0
# 2                                 1                 0                 0
# 3                                 0                 0                 0
# 4                                 0                 0                 0
# ...                             ...               ...               ...
# 3630                              1                 0                 0
# 3631                              0                 0                 0
# 3632                              0                 0                 0
# 3633                              0                 0                 0
# 3634                              0                 0                 0
#
# candidate_column  gen_lib_JOHNSON  gen_rep_TRUMP
# 0                              16            379
# 1                               1             14
# 2                              22            377
# 3                              10            300
# 4                               1             85
# ...                           ...            ...
# 3630                           16            275
# 3631                            5             79
# 3632                           40            515
# 3633                            5            140
# 3634                           15            188
#
# [3635 rows x 17 columns]

# %%
# Merge
combined = pd.merge(primary_result, general_result, on="precinct", how="inner")

# Convert DEM primary columns to numeric and calculate total
dem_cols = combined.filter(like="pri_dem_").columns
combined[dem_cols] = combined[dem_cols].apply(pd.to_numeric, errors="coerce")
combined["dem_primary_total"] = combined[dem_cols].sum(axis=1)

rep_cols = combined.filter(like="pri_rep_").columns
combined[rep_cols] = combined[rep_cols].apply(pd.to_numeric, errors="coerce")
combined["rep_primary_total"] = combined[rep_cols].sum(axis=1)

# Convert general election columns to numeric and calculate total

gdem_cols = combined.filter(like="gen_dem_").columns
combined[gdem_cols] = combined[gdem_cols].apply(pd.to_numeric, errors="coerce")
combined["dem_general_total"] = combined[gdem_cols].sum(axis=1)

grep_cols = combined.filter(like="gen_rep_").columns
combined[grep_cols] = combined[grep_cols].apply(pd.to_numeric, errors="coerce")
combined["rep_general_total"] = combined[grep_cols].sum(axis=1)

# Convert all numeric columns to int
for col in combined.columns[1:]:
    combined[col] = pd.to_numeric(combined[col], errors='coerce').fillna(0).astype(int)

# Identify filtered-out precincts
primary_precincts = set(primary_result["precinct"])
general_precincts = set(general_result["precinct"])
combined_precincts = set(combined["precinct"])

primary_filtered_out = primary_precincts - combined_precincts
general_filtered_out = general_precincts - combined_precincts


combined
# Out:
# candidate_column                                precinct  pri_dem_CLINTON  \
# 0                            ADAMSCITY OF ADAMS WARD 1-4              130
# 1                 ADAMSCITY OF WISCONSIN DELLS WARDS 5,9                1
# 2                           ADAMSTOWN OF ADAMS WARDS 1-3               79
# 3                        ADAMSTOWN OF BIG FLATS WARD 1-2               56
# 4                            ADAMSTOWN OF COLBURN WARD 1                6
# ...                                                  ...              ...
# 3477                        WOODVILLAGE OF HEWITT WARD 1               56
# 3478                     WOODVILLAGE OF MILLADORE WARD 1               14
# 3479               WOODVILLAGE OF PORT EDWARDS WARDS 1-3              136
# 3480                       WOODVILLAGE OF RUDOLPH WARD 1               35
# 3481                        WOODVILLAGE OF VESPER WARD 1               29
#
# candidate_column  pri_dem_FUENTE  pri_dem_O'MALLEY  pri_dem_SANDERS  \
# 0                              0                 1              123
# 1                              0                 0                5
# 2                              0                 3               81
# 3                              0                 0               89
# 4                              0                 0               17
# ...                          ...               ...              ...
# 3477                           0                 0               86
# 3478                           0                 0               22
# 3479                           0                 0              167
# 3480                           0                 0               44
# 3481                           0                 0               46
#
# candidate_column  pri_rep_BUSH  pri_rep_CARSON  pri_rep_CHRISTIE  \
# 0                            3               1                 0
# 1                            0               0                 0
# 2                            0               0                 0
# 3                            0               2                 0
# 4                            0               1                 0
# ...                        ...             ...               ...
# 3477                         0               2                 0
# 3478                         0               0                 0
# 3479                         2               6                 0
# 3480                         0               0                 0
# 3481                         0               0                 0
#
# candidate_column  pri_rep_CRUZ  pri_rep_FIORINA  ...  gen_ind_MCMULLIN  \
# 0                           83                0  ...                 4
# 1                            0                0  ...                 0
# 2                           86                0  ...                 3
# 3                           66                0  ...                 0
# 4                           13                0  ...                 0
# ...                        ...              ...  ...               ...
# 3477                       114                0  ...                 1
# 3478                        31                0  ...                 0
# 3479                       175                0  ...                 4
# 3480                        57                0  ...                 0
# 3481                        69                0  ...                 0
#
# candidate_column  gen_ind_MOOREHEAD  gen_ind_SCHOENKE  gen_ind_SOLTYSIK  \
# 0                                 2                 0                 0
# 1                                 0                 0                 0
# 2                                 1                 0                 0
# 3                                 0                 0                 0
# 4                                 0                 0                 0
# ...                             ...               ...               ...
# 3477                              1                 0                 0
# 3478                              0                 0                 0
# 3479                              0                 0                 0
# 3480                              0                 0                 0
# 3481                              0                 0                 0
#
# candidate_column  gen_lib_JOHNSON  gen_rep_TRUMP  dem_primary_total  \
# 0                              16            379                254
# 1                               1             14                  6
# 2                              22            377                163
# 3                              10            300                145
# 4                               1             85                 23
# ...                           ...            ...                ...
# 3477                           16            275                142
# 3478                            5             79                 36
# 3479                           40            515                303
# 3480                            5            140                 79
# 3481                           15            188                 75
#
# candidate_column  rep_primary_total  dem_general_total  rep_general_total
# 0                               251                329                379
# 1                                 6                  7                 14
# 2                               271                207                377
# 3                               196                169                300
# 4                                56                 42                 85
# ...                             ...                ...                ...
# 3477                            229                181                275
# 3478                             59                 47                 79
# 3479                            402                389                515
# 3480                             96                101                140
# 3481                            133                 89                188
#
# [3482 rows x 38 columns]

# %%
combined.to_csv("WI.csv", index=False)
# Step 3: Identify unmatched precincts and retrieve full rows
combined_precincts = set(combined["precinct"])

# Rows in primary_result but not in combined
primary_filtered_out = primary_result[~primary_result["precinct"].isin(combined_precincts)]
primary_filtered_out.to_csv("WI_primary_filtered.csv", index=False)

# Rows in general_result but not in combined
general_filtered_out = general_result[~general_result["precinct"].isin(combined_precincts)]
general_filtered_out.to_csv("WI_general_filtered.csv", index=False)

# %%
print(f"primary: {len(primary_precincts)}, general: {len(general_precincts)}, combined: {len(combined)}")
# Out:
# primary: 3579, general: 3635, combined: 3482

# %%
print(f"primary: {len(pri_combined_df['county'].unique())}, general: {len(gen_combined_df['county'].unique())}")
# Out:
# primary: 72, general: 72

# %%
pri_combined_df['jurisdiction'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'jurisdiction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1038], line 1
# ----> 1 pri_combined_df['jurisdiction'].unique()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'jurisdiction'

# %%
gen_combined_df['county'].unique()
# Out:
# array(['CARSON CITY', 'CHURCHILL', 'CLARK', 'DOUGLAS', 'ELKO',
#        'ESMERALDA', 'EUREKA', 'HUMBOLDT', 'LANDER', 'LINCOLN', 'LYON',
#        'MINERAL', 'NYE', 'PERSHING', 'STOREY', 'WASHOE', 'WHITE PINE'],
#       dtype=object)

# %%
primary_counties = set(pri_combined_df['jurisdiction'].dropna().str.strip().str.upper())
general_counties = set(gen_combined_df['county'].dropna().str.strip().str.upper())

diff = primary_counties - general_counties
print(f"Counties in primary but not in general: {len(diff)}")
print(diff)
# Out:
# Counties in primary but not in general: 1
# {'YE'}
